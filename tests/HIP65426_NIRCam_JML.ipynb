# %%
# Import the usual libraries
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Enable inline plotting at lower left
# %matplotlib inline

# %%
import os

# Progress bar
from tqdm.auto import trange, tqdm

from astropy.io import fits
from webbpsf_ext import robust

# %%
# Import the JWST class from spaceKLIP

from spaceKLIP.engine import JWST
# Out:
# WebbPSF log messages of level ERROR and above will be shown.
# WebbPSF log outputs will be directed to the screen.
# WebbPSF log messages of level ERROR and above will be shown.
# WebbPSF log outputs will be directed to the screen.
# webbpsf_ext log messages of level WARN and above will be shown.
# webbpsf_ext log outputs will be directed to the screen.

# %%
# Provide config file, or 'template' to use existing template
config_file = '/home/jarronl/GitHub/spaceKLIP/tests/HIP65426_NIRCam_JML.yaml'
pipeline = JWST(config_file)

# %%
# If desired, sort uncals files from MAST $JWSTDOWNLOAD_OUTDIR to SpaceKLIP directorys
# Creates symbolic links
pipeline.sort_files()

# %%
# Perform ramp fitting
pipeline.rampfit()
# Out:
# 2022-08-10 18:51:30,654 - stpipe.Coron1Pipeline - INFO - Coron1Pipeline instance created.
# [stpipe.Coron1Pipeline:INFO] Coron1Pipeline instance created.
# 2022-08-10 18:51:30,655 - stpipe.Coron1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# [stpipe.Coron1Pipeline.group_scale:INFO] GroupScaleStep instance created.
# 2022-08-10 18:51:30,656 - stpipe.Coron1Pipeline.dq_init - INFO - DQInitStep instance created.
# [stpipe.Coron1Pipeline.dq_init:INFO] DQInitStep instance created.
# 2022-08-10 18:51:30,657 - stpipe.Coron1Pipeline.saturation - INFO - SaturationStep instance created.
# [stpipe.Coron1Pipeline.saturation:INFO] SaturationStep instance created.
# 2022-08-10 18:51:30,658 - stpipe.Coron1Pipeline.ipc - INFO - IPCStep instance created.
# [stpipe.Coron1Pipeline.ipc:INFO] IPCStep instance created.
# 2022-08-10 18:51:30,659 - stpipe.Coron1Pipeline.superbias - INFO - SuperBiasStep instance created.
# [stpipe.Coron1Pipeline.superbias:INFO] SuperBiasStep instance created.
# 2022-08-10 18:51:30,660 - stpipe.Coron1Pipeline.refpix - INFO - RefPixStep instance created.
# [stpipe.Coron1Pipeline.refpix:INFO] RefPixStep instance created.
# 2022-08-10 18:51:30,661 - stpipe.Coron1Pipeline.rscd - INFO - RscdStep instance created.
# [stpipe.Coron1Pipeline.rscd:INFO] RscdStep instance created.
# 2022-08-10 18:51:30,662 - stpipe.Coron1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# [stpipe.Coron1Pipeline.firstframe:INFO] FirstFrameStep instance created.
# 2022-08-10 18:51:30,662 - stpipe.Coron1Pipeline.lastframe - INFO - LastFrameStep instance created.
# [stpipe.Coron1Pipeline.lastframe:INFO] LastFrameStep instance created.
# 2022-08-10 18:51:30,663 - stpipe.Coron1Pipeline.linearity - INFO - LinearityStep instance created.
# [stpipe.Coron1Pipeline.linearity:INFO] LinearityStep instance created.
# 2022-08-10 18:51:30,665 - stpipe.Coron1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# [stpipe.Coron1Pipeline.dark_current:INFO] DarkCurrentStep instance created.
# 2022-08-10 18:51:30,666 - stpipe.Coron1Pipeline.reset - INFO - ResetStep instance created.
# [stpipe.Coron1Pipeline.reset:INFO] ResetStep instance created.
# 2022-08-10 18:51:30,667 - stpipe.Coron1Pipeline.persistence - INFO - PersistenceStep instance created.
# [stpipe.Coron1Pipeline.persistence:INFO] PersistenceStep instance created.
# 2022-08-10 18:51:30,669 - stpipe.Coron1Pipeline.jump - INFO - JumpStep instance created.
# [stpipe.Coron1Pipeline.jump:INFO] JumpStep instance created.
# 2022-08-10 18:51:30,670 - stpipe.Coron1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# [stpipe.Coron1Pipeline.ramp_fit:INFO] RampFitStep instance created.
# 2022-08-10 18:51:30,671 - stpipe.Coron1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# [stpipe.Coron1Pipeline.gain_scale:INFO] GainScaleStep instance created.
# 2022-08-10 18:51:30,779 - stpipe.Coron1Pipeline - INFO - Step Coron1Pipeline running with args ('/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/jw01386001001_03108_00009_nrcalong_uncal.fits',).
# [stpipe.Coron1Pipeline:INFO] Step Coron1Pipeline running with args ('/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/jw01386001001_03108_00009_nrcalong_uncal.fits',).
# 2022-08-10 18:51:30,786 - stpipe.Coron1Pipeline - INFO - Step Coron1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'nrow_ref': True, 'ncol_ref': 0, 'grow_diagonal': False, 'save_intermediates': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'out ...
# [stpipe.Coron1Pipeline:INFO] Step Coron1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'nrow_ref': True, 'ncol_ref': 0, 'grow_diagonal': False, 'save_intermediates': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_u ...
# 2022-08-10 18:51:30,942 - stpipe.Coron1Pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_03108_00009_nrcalong_uncal.fits' reftypes = ['gain', 'ipc', 'linearity', 'mask', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias']
# [stpipe.Coron1Pipeline:INFO] Prefetching reference files for dataset: 'jw01386001001_03108_00009_nrcalong_uncal.fits' reftypes = ['gain', 'ipc', 'linearity', 'mask', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias']
# 2022-08-10 18:51:30,945 - stpipe.Coron1Pipeline - INFO - Prefetch for GAIN reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_gain_0056.fits'.
# [stpipe.Coron1Pipeline:INFO] Prefetch for GAIN reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_gain_0056.fits'.
# 2022-08-10 18:51:30,945 - stpipe.Coron1Pipeline - INFO - Prefetch for IPC reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_ipc_0028.fits'.
# [stpipe.Coron1Pipeline:INFO] Prefetch for IPC reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_ipc_0028.fits'.
# 2022-08-10 18:51:30,946 - stpipe.Coron1Pipeline - INFO - Prefetch for LINEARITY reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_linearity_0052.fits'.
# [stpipe.Coron1Pipeline:INFO] Prefetch for LINEARITY reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_linearity_0052.fits'.
# 2022-08-10 18:51:30,946 - stpipe.Coron1Pipeline - INFO - Prefetch for MASK reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_mask_0066.fits'.
# [stpipe.Coron1Pipeline:INFO] Prefetch for MASK reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_mask_0066.fits'.
# 2022-08-10 18:51:30,947 - stpipe.Coron1Pipeline - INFO - Prefetch for READNOISE reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_readnoise_0077.fits'.
# [stpipe.Coron1Pipeline:INFO] Prefetch for READNOISE reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_readnoise_0077.fits'.
# 2022-08-10 18:51:30,947 - stpipe.Coron1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# [stpipe.Coron1Pipeline:INFO] Prefetch for REFPIX reference file is 'N/A'.
# 2022-08-10 18:51:30,948 - stpipe.Coron1Pipeline - INFO - Prefetch for RESET reference file is 'N/A'.
# [stpipe.Coron1Pipeline:INFO] Prefetch for RESET reference file is 'N/A'.
# 2022-08-10 18:51:30,948 - stpipe.Coron1Pipeline - INFO - Prefetch for RSCD reference file is 'N/A'.
# [stpipe.Coron1Pipeline:INFO] Prefetch for RSCD reference file is 'N/A'.
# 2022-08-10 18:51:30,949 - stpipe.Coron1Pipeline - INFO - Prefetch for SATURATION reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_saturation_0084.fits'.
# [stpipe.Coron1Pipeline:INFO] Prefetch for SATURATION reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_saturation_0084.fits'.
# 2022-08-10 18:51:30,949 - stpipe.Coron1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_superbias_0044.fits'.
# [stpipe.Coron1Pipeline:INFO] Prefetch for SUPERBIAS reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_superbias_0044.fits'.
# [spaceKLIP.rampfit:INFO] Starting calwebb_coron1 ...
# 2022-08-10 18:51:31,203 - stpipe.Coron1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.group_scale:INFO] Step group_scale running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:31,204 - stpipe.Coron1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# [stpipe.Coron1Pipeline.group_scale:INFO] Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# 2022-08-10 18:51:31,233 - stpipe.Coron1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# [stpipe.Coron1Pipeline.group_scale:INFO] NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-08-10 18:51:31,234 - stpipe.Coron1Pipeline.group_scale - INFO - Step will be skipped
# [stpipe.Coron1Pipeline.group_scale:INFO] Step will be skipped
# 2022-08-10 18:51:31,236 - stpipe.Coron1Pipeline.group_scale - INFO - Step group_scale done
# [stpipe.Coron1Pipeline.group_scale:INFO] Step group_scale done
# 2022-08-10 18:51:31,335 - stpipe.Coron1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.dq_init:INFO] Step dq_init running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:31,336 - stpipe.Coron1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# [stpipe.Coron1Pipeline.dq_init:INFO] Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# 2022-08-10 18:51:31,351 - stpipe.Coron1Pipeline.dq_init - INFO - Using MASK reference file /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_mask_0066.fits
# [stpipe.Coron1Pipeline.dq_init:INFO] Using MASK reference file /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_mask_0066.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.dq_init.dq_initialization:INFO] Extracting mask subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-08-10 18:51:31,737 - stpipe.Coron1Pipeline.dq_init - INFO - Step dq_init done
# [stpipe.Coron1Pipeline.dq_init:INFO] Step dq_init done
# 2022-08-10 18:51:31,838 - stpipe.Coron1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.saturation:INFO] Step saturation running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:31,839 - stpipe.Coron1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'n_pix_grow_sat': 0}
# [stpipe.Coron1Pipeline.saturation:INFO] Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'n_pix_grow_sat': 0}
# 2022-08-10 18:51:31,854 - stpipe.Coron1Pipeline.saturation - INFO - Using SATURATION reference file /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_saturation_0084.fits
# [stpipe.Coron1Pipeline.saturation:INFO] Using SATURATION reference file /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_saturation_0084.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.saturation.saturation:INFO] Extracting reference file subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stcal.saturation.saturation:INFO] Detected 120 saturated pixels
# [stcal.saturation.saturation:INFO] Detected 0 A/D floor pixels
# 2022-08-10 18:51:32,213 - stpipe.Coron1Pipeline.saturation - INFO - Step saturation done
# [stpipe.Coron1Pipeline.saturation:INFO] Step saturation done
# 2022-08-10 18:51:32,319 - stpipe.Coron1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.ipc:INFO] Step ipc running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:32,320 - stpipe.Coron1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# [stpipe.Coron1Pipeline.ipc:INFO] Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# 2022-08-10 18:51:32,335 - stpipe.Coron1Pipeline.ipc - INFO - Using IPC reference file /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_ipc_0028.fits
# [stpipe.Coron1Pipeline.ipc:INFO] Using IPC reference file /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_ipc_0028.fits
# [jwst.ipc.ipc_corr:DEBUG] IPC corr using nints=4, ngroups=4, nframes=8, groupgap=2
# [jwst.ipc.ipc_corr:DEBUG] ipc_correction: nints=4, ngroups=4, size=320,320
# [jwst.ipc.ipc_corr:DEBUG] substrt1 = 492, subsize1 = 320, substrt2 = 1502, subsize2 = 320
# [jwst.ipc.ipc_corr:DEBUG] Number of reference pixels: bottom, top, left, right = 0, 0, 0, 0
# [jwst.ipc.ipc_corr:DEBUG] Shape of ipc image = (3, 3)
# 2022-08-10 18:51:32,377 - stpipe.Coron1Pipeline.ipc - INFO - Step ipc done
# [stpipe.Coron1Pipeline.ipc:INFO] Step ipc done
# 2022-08-10 18:51:32,476 - stpipe.Coron1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.superbias:INFO] Step superbias running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:32,477 - stpipe.Coron1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# [stpipe.Coron1Pipeline.superbias:INFO] Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# 2022-08-10 18:51:32,492 - stpipe.Coron1Pipeline.superbias - INFO - Using SUPERBIAS reference file /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_superbias_0044.fits
# [stpipe.Coron1Pipeline.superbias:INFO] Using SUPERBIAS reference file /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_superbias_0044.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# 2022-08-10 18:51:32,544 - stpipe.Coron1Pipeline.superbias - INFO - Step superbias done
# [stpipe.Coron1Pipeline.superbias:INFO] Step superbias done
# [spaceKLIP.rampfit:INFO] Flagging [True, True] references rows at [bottom, top] of array
# [spaceKLIP.rampfit:INFO] Flagging [0, 0] references rows at [left, right] of array
# 2022-08-10 18:51:32,646 - stpipe.Coron1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.refpix:INFO] Step refpix running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:32,647 - stpipe.Coron1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'odd_even_columns': True, 'use_side_ref_pixels': False, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# [stpipe.Coron1Pipeline.refpix:INFO] Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'odd_even_columns': True, 'use_side_ref_pixels': False, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# [jwst.lib.reffile_utils:DEBUG] Input exposure is a subarray readout
# [jwst.lib.reffile_utils:DEBUG] Input exposure is a subarray readout
# [jwst.refpix.reference_pixels:INFO] NIR subarray data
# [jwst.refpix.reference_pixels:INFO] Single readout amplifier used
# [jwst.refpix.reference_pixels:INFO] No valid reference pixels.  This step wil have no effect
# 2022-08-10 18:51:32,871 - stpipe.Coron1Pipeline.refpix - INFO - Step refpix done
# [stpipe.Coron1Pipeline.refpix:INFO] Step refpix done
# [spaceKLIP.rampfit:INFO] Removing reference pixel flags
# 2022-08-10 18:51:32,972 - stpipe.Coron1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.linearity:INFO] Step linearity running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:32,974 - stpipe.Coron1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# [stpipe.Coron1Pipeline.linearity:INFO] Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# 2022-08-10 18:51:32,988 - stpipe.Coron1Pipeline.linearity - INFO - Using Linearity reference file /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_linearity_0052.fits
# [stpipe.Coron1Pipeline.linearity:INFO] Using Linearity reference file /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_linearity_0052.fits
# [stcal.dynamicdq:WARNING] Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-08-10 18:51:33,124 - stpipe.Coron1Pipeline.linearity - INFO - Step linearity done
# [stpipe.Coron1Pipeline.linearity:INFO] Step linearity done
# 2022-08-10 18:51:33,238 - stpipe.Coron1Pipeline.persistence - INFO - Step persistence running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.persistence:INFO] Step persistence running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:33,239 - stpipe.Coron1Pipeline.persistence - INFO - Step persistence parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}
# [stpipe.Coron1Pipeline.persistence:INFO] Step persistence parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}
# 2022-08-10 18:51:33,240 - stpipe.Coron1Pipeline.persistence - INFO - Step skipped.
# [stpipe.Coron1Pipeline.persistence:INFO] Step skipped.
# 2022-08-10 18:51:33,242 - stpipe.Coron1Pipeline.persistence - INFO - Step persistence done
# [stpipe.Coron1Pipeline.persistence:INFO] Step persistence done
# 2022-08-10 18:51:33,336 - stpipe.Coron1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.dark_current:INFO] Step dark_current running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:33,337 - stpipe.Coron1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'dark_output': None}
# [stpipe.Coron1Pipeline.dark_current:INFO] Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'dark_output': None}
# 2022-08-10 18:51:33,338 - stpipe.Coron1Pipeline.dark_current - INFO - Step skipped.
# [stpipe.Coron1Pipeline.dark_current:INFO] Step skipped.
# 2022-08-10 18:51:33,340 - stpipe.Coron1Pipeline.dark_current - INFO - Step dark_current done
# [stpipe.Coron1Pipeline.dark_current:INFO] Step dark_current done
# 2022-08-10 18:51:33,434 - stpipe.Coron1Pipeline.jump - INFO - Step jump running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.jump:INFO] Step jump running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:33,436 - stpipe.Coron1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'rejection_threshold': 5, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0}
# [stpipe.Coron1Pipeline.jump:INFO] Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'rejection_threshold': 5, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0}
# 2022-08-10 18:51:33,443 - stpipe.Coron1Pipeline.jump - INFO - CR rejection threshold = 5 sigma
# [stpipe.Coron1Pipeline.jump:INFO] CR rejection threshold = 5 sigma
# 2022-08-10 18:51:33,452 - stpipe.Coron1Pipeline.jump - INFO - Using GAIN reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_gain_0056.fits
# [stpipe.Coron1Pipeline.jump:INFO] Using GAIN reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_gain_0056.fits
# 2022-08-10 18:51:33,485 - stpipe.Coron1Pipeline.jump - INFO - Using READNOISE reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_readnoise_0077.fits
# [stpipe.Coron1Pipeline.jump:INFO] Using READNOISE reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_readnoise_0077.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.jump.jump:INFO] Extracting gain subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [jwst.lib.reffile_utils:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stcal.jump.jump:INFO] Executing two-point difference method
# [stcal.jump.twopoint_difference:INFO] Working on integration 1:
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 289 pixels with at least one CR from four groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stcal.jump.twopoint_difference:INFO] Working on integration 2:
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 233 pixels with at least one CR from four groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stcal.jump.twopoint_difference:INFO] Working on integration 3:
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 254 pixels with at least one CR from four groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stcal.jump.twopoint_difference:INFO] Working on integration 4:
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 213 pixels with at least one CR from four groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 1 pixels with at least one CR from three groups.
# [stcal.jump.jump:INFO] Total elapsed time = 0.150593 sec
# 2022-08-10 18:51:33,679 - stpipe.Coron1Pipeline.jump - INFO - The execution time in seconds: 0.235620
# [stpipe.Coron1Pipeline.jump:INFO] The execution time in seconds: 0.235620
# 2022-08-10 18:51:33,683 - stpipe.Coron1Pipeline.jump - INFO - Step jump done
# [stpipe.Coron1Pipeline.jump:INFO] Step jump done
# 2022-08-10 18:51:33,787 - stpipe.Coron1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.ramp_fit:INFO] Step ramp_fit running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:33,788 - stpipe.Coron1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'quarter'}
# [stpipe.Coron1Pipeline.ramp_fit:INFO] Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'quarter'}
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using READNOISE reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_readnoise_0077.fits
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using GAIN reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_gain_0056.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.ramp_fitting.ramp_fit_step:INFO] Extracting gain subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [jwst.lib.reffile_utils:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using algorithm = ols
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using weighting = optimal
# [stcal.ramp_fitting.utils:DEBUG] Found 24 possible cores to use for ramp fitting
# [stcal.ramp_fitting.ols_fit:INFO] Number of processors used for multiprocessing: 6
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 19:
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -109.436302, 0.041963, 83.944832, 1.835315
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 17280
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (54, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 54, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 54
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.125774
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 17:
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -216.430878, 0.139692, 205.809326, 3.396352
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 16960
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 53
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.115785
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 23:
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -31.768232, 2.644729, 4276.567383, 35.928688
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 16960
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 53
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 18:
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.137527
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -0.518377, 0.807174, 4142.404785, 32.067890
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 16960
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 53
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.146469
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 27:
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -0.521184, 0.078657, 140.827011, 2.166257
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 17280
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (54, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 54, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 54
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.182275
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 25:
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -10.125574, 0.682288, 4101.847656, 42.757484
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 16960
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 53
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.180265
# 2022-08-10 18:51:34,180 - stpipe.Coron1Pipeline.ramp_fit - INFO - Step ramp_fit done
# [stpipe.Coron1Pipeline.ramp_fit:INFO] Step ramp_fit done
# 2022-08-10 18:51:34,334 - stpipe.Coron1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step gain_scale running with args (<ImageModel(320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# 2022-08-10 18:51:34,336 - stpipe.Coron1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'rate', 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'rate', 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# 2022-08-10 18:51:34,390 - stpipe.Coron1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# [stpipe.Coron1Pipeline.gain_scale:INFO] GAINFACT not found in gain reference file
# 2022-08-10 18:51:34,391 - stpipe.Coron1Pipeline.gain_scale - INFO - Step will be skipped
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step will be skipped
# 2022-08-10 18:51:34,398 - stpipe.Coron1Pipeline.gain_scale - INFO - Step gain_scale done
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step gain_scale done
# 2022-08-10 18:51:34,547 - stpipe.Coron1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step gain_scale running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00009_nrcalong_uncal.fits>,).
# ...
# 2022-08-10 18:52:19,760 - stpipe.Coron1Pipeline.jump - INFO - Using READNOISE reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_readnoise_0077.fits
# [stpipe.Coron1Pipeline.jump:INFO] Using READNOISE reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_readnoise_0077.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.jump.jump:INFO] Extracting gain subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [jwst.lib.reffile_utils:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stcal.jump.jump:INFO] Executing two-point difference method
# [stcal.jump.twopoint_difference:INFO] Working on integration 1:
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 286 pixels with at least one CR from four groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stcal.jump.twopoint_difference:INFO] Working on integration 2:
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 242 pixels with at least one CR from four groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stcal.jump.twopoint_difference:INFO] Working on integration 3:
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 260 pixels with at least one CR from four groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stcal.jump.twopoint_difference:INFO] Working on integration 4:
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 204 pixels with at least one CR from four groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stcal.jump.jump:INFO] Total elapsed time = 0.160918 sec
# 2022-08-10 18:52:19,970 - stpipe.Coron1Pipeline.jump - INFO - The execution time in seconds: 0.257584
# [stpipe.Coron1Pipeline.jump:INFO] The execution time in seconds: 0.257584
# 2022-08-10 18:52:19,975 - stpipe.Coron1Pipeline.jump - INFO - Step jump done
# [stpipe.Coron1Pipeline.jump:INFO] Step jump done
# 2022-08-10 18:52:20,102 - stpipe.Coron1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00002_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.ramp_fit:INFO] Step ramp_fit running with args (<RampModel(4, 4, 320, 320) from jw01386001001_03108_00002_nrcalong_uncal.fits>,).
# 2022-08-10 18:52:20,104 - stpipe.Coron1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'quarter'}
# [stpipe.Coron1Pipeline.ramp_fit:INFO] Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'quarter'}
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using READNOISE reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_readnoise_0077.fits
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using GAIN reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_gain_0056.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.ramp_fitting.ramp_fit_step:INFO] Extracting gain subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [jwst.lib.reffile_utils:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using algorithm = ols
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using weighting = optimal
# [stcal.ramp_fitting.utils:DEBUG] Found 24 possible cores to use for ramp fitting
# [stcal.ramp_fitting.ols_fit:INFO] Number of processors used for multiprocessing: 6
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 27:
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -0.436977, 0.075651, 140.375519, 2.150092
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 17280
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (54, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 54, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 54
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.119896
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 19:
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -109.337929, 0.061523, 83.814842, 1.855789
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 18:
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 17280
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -0.329648, 0.779032, 4140.258789, 32.041862
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (54, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 16960
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 54, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 54
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 53
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.124069
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.120344
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 23:
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -33.400383, 2.599552, 4277.554688, 35.889725
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 16960
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 53
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 17:
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.121071
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -216.902954, 0.130065, 205.880737, 3.306877
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 16960
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 53
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.120609
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 25:
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -10.387178, 0.703236, 4103.554688, 42.762104
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 16960
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 53, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 53
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 4
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.122748
# 2022-08-10 18:52:20,444 - stpipe.Coron1Pipeline.ramp_fit - INFO - Step ramp_fit done
# [stpipe.Coron1Pipeline.ramp_fit:INFO] Step ramp_fit done
# 2022-08-10 18:52:20,570 - stpipe.Coron1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(320, 320) from jw01386001001_03108_00002_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step gain_scale running with args (<ImageModel(320, 320) from jw01386001001_03108_00002_nrcalong_uncal.fits>,).
# 2022-08-10 18:52:20,571 - stpipe.Coron1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'rate', 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'rate', 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# 2022-08-10 18:52:20,609 - stpipe.Coron1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# [stpipe.Coron1Pipeline.gain_scale:INFO] GAINFACT not found in gain reference file
# 2022-08-10 18:52:20,610 - stpipe.Coron1Pipeline.gain_scale - INFO - Step will be skipped
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step will be skipped
# 2022-08-10 18:52:20,613 - stpipe.Coron1Pipeline.gain_scale - INFO - Step gain_scale done
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step gain_scale done
# 2022-08-10 18:52:20,729 - stpipe.Coron1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00002_nrcalong_uncal.fits>,).
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step gain_scale running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00002_nrcalong_uncal.fits>,).
# 2022-08-10 18:52:20,731 - stpipe.Coron1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'rateints', 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'rateints', 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R'}
# 2022-08-10 18:52:20,771 - stpipe.Coron1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# [stpipe.Coron1Pipeline.gain_scale:INFO] GAINFACT not found in gain reference file
# 2022-08-10 18:52:20,772 - stpipe.Coron1Pipeline.gain_scale - INFO - Step will be skipped
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step will be skipped
# 2022-08-10 18:52:20,776 - stpipe.Coron1Pipeline.gain_scale - INFO - Step gain_scale done
# [stpipe.Coron1Pipeline.gain_scale:INFO] Step gain_scale done
# 2022-08-10 18:52:20,835 - stpipe.Coron1Pipeline - INFO - Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rateints.fits
# [stpipe.Coron1Pipeline:INFO] Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rateints.fits
# [spaceKLIP.rampfit:INFO] ... ending calwebb_coron1
# [jwst.stpipe.core:INFO] Results used CRDS context: jwst_0928.pmap
# 2022-08-10 18:52:20,885 - stpipe.Coron1Pipeline - INFO - Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rate.fits
# [stpipe.Coron1Pipeline:INFO] Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rate.fits
# 2022-08-10 18:52:20,886 - stpipe.Coron1Pipeline - INFO - Step Coron1Pipeline done
# [stpipe.Coron1Pipeline:INFO] Step Coron1Pipeline done

# %%
# Perform image processing
pipeline.imgprocess()
# Out:
# 2022-08-10 18:53:34,433 - stpipe.Coron2Pipeline - INFO - Coron2Pipeline instance created.
# --> Found 11 file(s) under: /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/
# [stpipe.Coron2Pipeline:INFO] Coron2Pipeline instance created.
# 2022-08-10 18:53:34,435 - stpipe.Coron2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# [stpipe.Coron2Pipeline.bkg_subtract:INFO] BackgroundStep instance created.
# 2022-08-10 18:53:34,437 - stpipe.Coron2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# [stpipe.Coron2Pipeline.assign_wcs:INFO] AssignWcsStep instance created.
# 2022-08-10 18:53:34,439 - stpipe.Coron2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# [stpipe.Coron2Pipeline.flat_field:INFO] FlatFieldStep instance created.
# 2022-08-10 18:53:34,441 - stpipe.Coron2Pipeline.photom - INFO - PhotomStep instance created.
# [stpipe.Coron2Pipeline.photom:INFO] PhotomStep instance created.
# 2022-08-10 18:53:34,443 - stpipe.Coron2Pipeline.resample - INFO - ResampleStep instance created.
# [stpipe.Coron2Pipeline.resample:INFO] ResampleStep instance created.
# 2022-08-10 18:53:34,445 - stpipe.Coron2Pipeline.outlier_step - INFO - OutlierDetectionStep instance created.
# [stpipe.Coron2Pipeline.outlier_step:INFO] OutlierDetectionStep instance created.
# 2022-08-10 18:53:34,447 - stpipe.Coron2Pipeline.clean_step - INFO - CleanPixStep instance created.
# [stpipe.Coron2Pipeline.clean_step:INFO] CleanPixStep instance created.
# 2022-08-10 18:53:34,627 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline running with args ('/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong_rateints.fits',).
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline running with args ('/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong_rateints.fits',).
# 2022-08-10 18:53:34,634 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF_CLEAN', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'find_outliers': True, 'clean_data': True, 'clean_only': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'outlier_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'clean_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'outlier_type': 'bpclean', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}}}
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF_CLEAN', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'find_outliers': True, 'clean_data': True, 'clean_only': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'outlier_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'clean_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'outlier_type': 'bpclean', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}}}
# 2022-08-10 18:53:34,696 - stpipe.Coron2Pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_03108_00001_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# [stpipe.Coron2Pipeline:INFO] Prefetching reference files for dataset: 'jw01386001001_03108_00001_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-08-10 18:53:34,700 - stpipe.Coron2Pipeline - INFO - Prefetch for AREA reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for AREA reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# 2022-08-10 18:53:34,700 - stpipe.Coron2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for CAMERA reference file is 'N/A'.
# 2022-08-10 18:53:34,701 - stpipe.Coron2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-08-10 18:53:34,702 - stpipe.Coron2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DFLAT reference file is 'N/A'.
# 2022-08-10 18:53:34,703 - stpipe.Coron2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DISPERSER reference file is 'N/A'.
# 2022-08-10 18:53:34,703 - stpipe.Coron2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DISTORTION reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf'.
# 2022-08-10 18:53:34,705 - stpipe.Coron2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DRIZPARS reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# 2022-08-10 18:53:34,705 - stpipe.Coron2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FFLAT reference file is 'N/A'.
# 2022-08-10 18:53:34,706 - stpipe.Coron2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FILTEROFFSET reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf'.
# 2022-08-10 18:53:34,706 - stpipe.Coron2Pipeline - INFO - Prefetch for FLAT reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FLAT reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits'.
# 2022-08-10 18:53:34,708 - stpipe.Coron2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FORE reference file is 'N/A'.
# 2022-08-10 18:53:34,709 - stpipe.Coron2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FPA reference file is 'N/A'.
# 2022-08-10 18:53:34,710 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUFORE reference file is 'N/A'.
# 2022-08-10 18:53:34,711 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUPOST reference file is 'N/A'.
# 2022-08-10 18:53:34,712 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-08-10 18:53:34,712 - stpipe.Coron2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for MSA reference file is 'N/A'.
# 2022-08-10 18:53:34,713 - stpipe.Coron2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for OTE reference file is 'N/A'.
# 2022-08-10 18:53:34,714 - stpipe.Coron2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for PHOTOM reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits'.
# 2022-08-10 18:53:34,715 - stpipe.Coron2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for REGIONS reference file is 'N/A'.
# 2022-08-10 18:53:34,716 - stpipe.Coron2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SFLAT reference file is 'N/A'.
# 2022-08-10 18:53:34,716 - stpipe.Coron2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SPECWCS reference file is 'N/A'.
# 2022-08-10 18:53:34,717 - stpipe.Coron2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-08-10 18:53:34,718 - stpipe.Coron2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-08-10 18:53:34,719 - stpipe.Coron2Pipeline - INFO - Starting calwebb_coron2 ...
# [stpipe.Coron2Pipeline:INFO] Starting calwebb_coron2 ...
# 2022-08-10 18:53:34,720 - stpipe.Coron2Pipeline - INFO - Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong
# [stpipe.Coron2Pipeline:INFO] Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong
# 2022-08-10 18:53:34,721 - stpipe.Coron2Pipeline - INFO - Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong_rateints.fits ...
# [stpipe.Coron2Pipeline:INFO] Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong_rateints.fits ...
# 2022-08-10 18:53:34,950 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# 2022-08-10 18:53:34,952 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [jwst.assign_wcs.assign_wcs_step:DEBUG] reference files used in assign_wcs: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [jwst.assign_wcs.nircam:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [jwst.assign_wcs.nircam:DEBUG] Offsets from filteroffset file are 0.0, 0.0
# [jwst.assign_wcs.util:INFO] Update S_REGION to POLYGON ICRS  209.562497407 -42.102352890 209.569569022 -42.104261422 209.572080710 -42.099077093 209.565008403 -42.097159277
# [jwst.assign_wcs.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  209.562497407 -42.102352890 209.569569022 -42.104261422 209.572080710 -42.099077093 209.565008403 -42.097159277
# [jwst.assign_wcs.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-08-10 18:53:35,357 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs done
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs done
# 2022-08-10 18:53:35,536 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# 2022-08-10 18:53:35,538 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Coron2Pipeline.flat_field:DEBUG] Input is CubeModel of exposure type NRC_CORON
# [stpipe.Coron2Pipeline.flat_field:DEBUG] Using FLAT reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type FFLAT
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type SFLAT
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type DFLAT
# [jwst.flatfield.flat_field:DEBUG] Flat field correction for non-NIRSpec modes.
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.flatfield.flat_field:INFO] Extracting matching subarray from flat
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-08-10 18:53:35,773 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field done
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field done
# 2022-08-10 18:53:35,944 - stpipe.Coron2Pipeline.photom - INFO - Step photom running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.photom:INFO] Step photom running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# 2022-08-10 18:53:35,946 - stpipe.Coron2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'inverse': False, 'source_type': None}
# [stpipe.Coron2Pipeline.photom:INFO] Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'inverse': False, 'source_type': None}
# [stpipe.Coron2Pipeline.photom:DEBUG] Input is CubeModel
# 2022-08-10 18:53:35,985 - stpipe.Coron2Pipeline.photom - INFO - Using photom reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits
# [stpipe.Coron2Pipeline.photom:INFO] Using photom reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits
# 2022-08-10 18:53:35,987 - stpipe.Coron2Pipeline.photom - INFO - Using area reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits
# [stpipe.Coron2Pipeline.photom:INFO] Using area reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits
# [jwst.photom.photom:INFO] Using instrument: NIRCAM
# [jwst.photom.photom:INFO]  detector: NRCALONG
# [jwst.photom.photom:INFO]  exp_type: NRC_CORON
# [jwst.photom.photom:INFO]  filter: F300M
# [jwst.photom.photom:INFO]  pupil: MASKRND
# [jwst.photom.photom:INFO] Pixel area map copied to output.
# [jwst.photom.photom:DEBUG] PIXAR_SR = 9.31e-14, PIXAR_A2 = 0.00396
# [jwst.photom.photom:INFO] PHOTMJSR value: 7.04474
# 2022-08-10 18:53:36,155 - stpipe.Coron2Pipeline.photom - INFO - Step photom done
# [stpipe.Coron2Pipeline.photom:INFO] Step photom done
# 2022-08-10 18:53:36,156 - stpipe.Coron2Pipeline - INFO - Finished processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong
# [stpipe.Coron2Pipeline:INFO] Finished processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong
# 2022-08-10 18:53:36,331 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# 2022-08-10 18:53:36,333 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2022-08-10 18:53:36,342 - stpipe.Coron2Pipeline.outlier_step - INFO - Performing outlier detection with 4 inputs
# [stpipe.Coron2Pipeline.outlier_step:INFO] Performing outlier detection with 4 inputs
# [stpipe.Coron2Pipeline.outlier_step:DEBUG] Using OutlierDetection class for outlier_detection
# [jwst.outlier_detection.outlier_detection:DEBUG] Converting CubeModel to ModelContainer with 4 images
# [jwst.outlier_detection.outlier_detection:DEBUG] Defined output product suffix as: _outlier_i2d.fits
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:INFO] Flagging outliers
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 25 (0.02%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 54 (0.05%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 27 (0.03%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 19 (0.02%)
# 2022-08-10 18:53:36,800 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step done
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step done
# 2022-08-10 18:53:36,977 - stpipe.Coron2Pipeline.clean_step - INFO - Step clean_step running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.clean_step:INFO] Step clean_step running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# 2022-08-10 18:53:36,979 - stpipe.Coron2Pipeline.clean_step - INFO - Step clean_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'outlier_type': 'bpclean', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}
# [stpipe.Coron2Pipeline.clean_step:INFO] Step clean_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'outlier_type': 'bpclean', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}
# 2022-08-10 18:53:36,987 - stpipe.Coron2Pipeline.clean_step - INFO - Performing bpclean/bpfix cleaning algorithm
# [stpipe.Coron2Pipeline.clean_step:INFO] Performing bpclean/bpfix cleaning algorithm
# 2022-08-10 18:53:39,213 - stpipe.Coron2Pipeline.clean_step - INFO - ... Completed bpclean/bpfix cleaning.
# [stpipe.Coron2Pipeline.clean_step:INFO] ... Completed bpclean/bpfix cleaning.
# 2022-08-10 18:53:39,216 - stpipe.Coron2Pipeline.clean_step - INFO - Step clean_step done
# [stpipe.Coron2Pipeline.clean_step:INFO] Step clean_step done
# 2022-08-10 18:53:39,218 - stpipe.Coron2Pipeline - INFO - ... ending calwebb_coron2
# [stpipe.Coron2Pipeline:INFO] ... ending calwebb_coron2
# [jwst.stpipe.core:INFO] Results used CRDS context: jwst_0928.pmap
# 2022-08-10 18:53:39,350 - stpipe.Coron2Pipeline - INFO - Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF_CLEAN/jw01386001001_03108_00001_nrcalong_calints.fits
# [stpipe.Coron2Pipeline:INFO] Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF_CLEAN/jw01386001001_03108_00001_nrcalong_calints.fits
# 2022-08-10 18:53:39,351 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline done
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline done
# 2022-08-10 18:53:39,480 - stpipe.Coron2Pipeline - INFO - Coron2Pipeline instance created.
# [stpipe.Coron2Pipeline:INFO] Coron2Pipeline instance created.
# 2022-08-10 18:53:39,533 - stpipe.Coron2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# [stpipe.Coron2Pipeline.bkg_subtract:INFO] BackgroundStep instance created.
# 2022-08-10 18:53:39,536 - stpipe.Coron2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# [stpipe.Coron2Pipeline.assign_wcs:INFO] AssignWcsStep instance created.
# 2022-08-10 18:53:39,538 - stpipe.Coron2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# [stpipe.Coron2Pipeline.flat_field:INFO] FlatFieldStep instance created.
# 2022-08-10 18:53:39,539 - stpipe.Coron2Pipeline.photom - INFO - PhotomStep instance created.
# [stpipe.Coron2Pipeline.photom:INFO] PhotomStep instance created.
# 2022-08-10 18:53:39,541 - stpipe.Coron2Pipeline.resample - INFO - ResampleStep instance created.
# [stpipe.Coron2Pipeline.resample:INFO] ResampleStep instance created.
# 2022-08-10 18:53:39,543 - stpipe.Coron2Pipeline.outlier_step - INFO - OutlierDetectionStep instance created.
# [stpipe.Coron2Pipeline.outlier_step:INFO] OutlierDetectionStep instance created.
# 2022-08-10 18:53:39,544 - stpipe.Coron2Pipeline.clean_step - INFO - CleanPixStep instance created.
# [stpipe.Coron2Pipeline.clean_step:INFO] CleanPixStep instance created.
# 2022-08-10 18:53:39,677 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline running with args ('/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rateints.fits',).
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline running with args ('/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rateints.fits',).
# 2022-08-10 18:53:39,682 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF_CLEAN', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'find_outliers': True, 'clean_data': True, 'clean_only': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'outlier_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'clean_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'outlier_type': 'bpclean', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}}}
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF_CLEAN', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'find_outliers': True, 'clean_data': True, 'clean_only': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'outlier_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'clean_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'outlier_type': 'bpclean', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}}}
# 2022-08-10 18:53:39,727 - stpipe.Coron2Pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_03108_00002_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# [stpipe.Coron2Pipeline:INFO] Prefetching reference files for dataset: 'jw01386001001_03108_00002_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-08-10 18:53:39,731 - stpipe.Coron2Pipeline - INFO - Prefetch for AREA reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for AREA reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# 2022-08-10 18:53:39,731 - stpipe.Coron2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for CAMERA reference file is 'N/A'.
# 2022-08-10 18:53:39,732 - stpipe.Coron2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-08-10 18:53:39,733 - stpipe.Coron2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DFLAT reference file is 'N/A'.
# 2022-08-10 18:53:39,733 - stpipe.Coron2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DISPERSER reference file is 'N/A'.
# 2022-08-10 18:53:39,735 - stpipe.Coron2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DISTORTION reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf'.
# 2022-08-10 18:53:39,736 - stpipe.Coron2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DRIZPARS reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# 2022-08-10 18:53:39,737 - stpipe.Coron2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FFLAT reference file is 'N/A'.
# 2022-08-10 18:53:39,738 - stpipe.Coron2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FILTEROFFSET reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf'.
# 2022-08-10 18:53:39,739 - stpipe.Coron2Pipeline - INFO - Prefetch for FLAT reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FLAT reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits'.
# 2022-08-10 18:53:39,740 - stpipe.Coron2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FORE reference file is 'N/A'.
# 2022-08-10 18:53:39,741 - stpipe.Coron2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FPA reference file is 'N/A'.
# 2022-08-10 18:53:39,741 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUFORE reference file is 'N/A'.
# 2022-08-10 18:53:39,742 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUPOST reference file is 'N/A'.
# 2022-08-10 18:53:39,743 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-08-10 18:53:39,744 - stpipe.Coron2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for MSA reference file is 'N/A'.
# 2022-08-10 18:53:39,744 - stpipe.Coron2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for OTE reference file is 'N/A'.
# 2022-08-10 18:53:39,745 - stpipe.Coron2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for PHOTOM reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits'.
# 2022-08-10 18:53:39,746 - stpipe.Coron2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for REGIONS reference file is 'N/A'.
# 2022-08-10 18:53:39,746 - stpipe.Coron2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SFLAT reference file is 'N/A'.
# 2022-08-10 18:53:39,747 - stpipe.Coron2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SPECWCS reference file is 'N/A'.
# 2022-08-10 18:53:39,748 - stpipe.Coron2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-08-10 18:53:39,748 - stpipe.Coron2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-08-10 18:53:39,749 - stpipe.Coron2Pipeline - INFO - Starting calwebb_coron2 ...
# [stpipe.Coron2Pipeline:INFO] Starting calwebb_coron2 ...
# 2022-08-10 18:53:39,750 - stpipe.Coron2Pipeline - INFO - Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong
# [stpipe.Coron2Pipeline:INFO] Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong
# 2022-08-10 18:53:39,751 - stpipe.Coron2Pipeline - INFO - Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rateints.fits ...
# [stpipe.Coron2Pipeline:INFO] Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rateints.fits ...
# 2022-08-10 18:53:39,923 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00002_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00002_nrcalong_rateints.fits>,).
# 2022-08-10 18:53:39,925 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [jwst.assign_wcs.assign_wcs_step:DEBUG] reference files used in assign_wcs: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# ...
# [stpipe.Coron2Pipeline:INFO] Prefetch for SFLAT reference file is 'N/A'.
# 2022-08-10 18:54:16,139 - stpipe.Coron2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SPECWCS reference file is 'N/A'.
# 2022-08-10 18:54:16,139 - stpipe.Coron2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-08-10 18:54:16,140 - stpipe.Coron2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-08-10 18:54:16,141 - stpipe.Coron2Pipeline - INFO - Starting calwebb_coron2 ...
# [stpipe.Coron2Pipeline:INFO] Starting calwebb_coron2 ...
# 2022-08-10 18:54:16,142 - stpipe.Coron2Pipeline - INFO - Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong
# [stpipe.Coron2Pipeline:INFO] Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong
# 2022-08-10 18:54:16,143 - stpipe.Coron2Pipeline - INFO - Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong_rateints.fits ...
# [stpipe.Coron2Pipeline:INFO] Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong_rateints.fits ...
# 2022-08-10 18:54:16,314 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# 2022-08-10 18:54:16,315 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [jwst.assign_wcs.assign_wcs_step:DEBUG] reference files used in assign_wcs: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [jwst.assign_wcs.nircam:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [jwst.assign_wcs.nircam:DEBUG] Offsets from filteroffset file are 0.0, 0.0
# [jwst.assign_wcs.util:INFO] Update S_REGION to POLYGON ICRS  201.143692896 -51.505350264 201.151434275 -51.508170525 201.155876000 -51.503405313 201.148136480 -51.500575900
# [jwst.assign_wcs.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  201.143692896 -51.505350264 201.151434275 -51.508170525 201.155876000 -51.503405313 201.148136480 -51.500575900
# [jwst.assign_wcs.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-08-10 18:54:16,557 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs done
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs done
# 2022-08-10 18:54:16,696 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# 2022-08-10 18:54:16,698 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Coron2Pipeline.flat_field:DEBUG] Input is CubeModel of exposure type NRC_CORON
# [stpipe.Coron2Pipeline.flat_field:DEBUG] Using FLAT reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type FFLAT
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type SFLAT
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type DFLAT
# [jwst.flatfield.flat_field:DEBUG] Flat field correction for non-NIRSpec modes.
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.flatfield.flat_field:INFO] Extracting matching subarray from flat
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-08-10 18:54:16,865 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field done
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field done
# 2022-08-10 18:54:16,997 - stpipe.Coron2Pipeline.photom - INFO - Step photom running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.photom:INFO] Step photom running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# 2022-08-10 18:54:16,998 - stpipe.Coron2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'inverse': False, 'source_type': None}
# [stpipe.Coron2Pipeline.photom:INFO] Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'inverse': False, 'source_type': None}
# [stpipe.Coron2Pipeline.photom:DEBUG] Input is CubeModel
# 2022-08-10 18:54:17,019 - stpipe.Coron2Pipeline.photom - INFO - Using photom reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits
# [stpipe.Coron2Pipeline.photom:INFO] Using photom reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits
# 2022-08-10 18:54:17,020 - stpipe.Coron2Pipeline.photom - INFO - Using area reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits
# [stpipe.Coron2Pipeline.photom:INFO] Using area reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits
# [jwst.photom.photom:INFO] Using instrument: NIRCAM
# [jwst.photom.photom:INFO]  detector: NRCALONG
# [jwst.photom.photom:INFO]  exp_type: NRC_CORON
# [jwst.photom.photom:INFO]  filter: F300M
# [jwst.photom.photom:INFO]  pupil: MASKRND
# [jwst.photom.photom:INFO] Pixel area map copied to output.
# [jwst.photom.photom:DEBUG] PIXAR_SR = 9.31e-14, PIXAR_A2 = 0.00396
# [jwst.photom.photom:INFO] PHOTMJSR value: 7.04474
# 2022-08-10 18:54:17,126 - stpipe.Coron2Pipeline.photom - INFO - Step photom done
# [stpipe.Coron2Pipeline.photom:INFO] Step photom done
# 2022-08-10 18:54:17,126 - stpipe.Coron2Pipeline - INFO - Finished processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong
# [stpipe.Coron2Pipeline:INFO] Finished processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong
# 2022-08-10 18:54:17,256 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# 2022-08-10 18:54:17,258 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2022-08-10 18:54:17,268 - stpipe.Coron2Pipeline.outlier_step - INFO - Performing outlier detection with 4 inputs
# [stpipe.Coron2Pipeline.outlier_step:INFO] Performing outlier detection with 4 inputs
# [stpipe.Coron2Pipeline.outlier_step:DEBUG] Using OutlierDetection class for outlier_detection
# [jwst.outlier_detection.outlier_detection:DEBUG] Converting CubeModel to ModelContainer with 4 images
# [jwst.outlier_detection.outlier_detection:DEBUG] Defined output product suffix as: _outlier_i2d.fits
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:INFO] Flagging outliers
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 57 (0.06%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 21 (0.02%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 12 (0.01%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 23 (0.02%)
# 2022-08-10 18:54:17,589 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step done
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step done
# 2022-08-10 18:54:17,736 - stpipe.Coron2Pipeline.clean_step - INFO - Step clean_step running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.clean_step:INFO] Step clean_step running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# 2022-08-10 18:54:17,738 - stpipe.Coron2Pipeline.clean_step - INFO - Step clean_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'outlier_type': 'bpclean', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}
# [stpipe.Coron2Pipeline.clean_step:INFO] Step clean_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'outlier_type': 'bpclean', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}
# 2022-08-10 18:54:17,744 - stpipe.Coron2Pipeline.clean_step - INFO - Performing bpclean/bpfix cleaning algorithm
# [stpipe.Coron2Pipeline.clean_step:INFO] Performing bpclean/bpfix cleaning algorithm
# 2022-08-10 18:54:19,613 - stpipe.Coron2Pipeline.clean_step - INFO - ... Completed bpclean/bpfix cleaning.
# [stpipe.Coron2Pipeline.clean_step:INFO] ... Completed bpclean/bpfix cleaning.
# 2022-08-10 18:54:19,615 - stpipe.Coron2Pipeline.clean_step - INFO - Step clean_step done
# [stpipe.Coron2Pipeline.clean_step:INFO] Step clean_step done
# 2022-08-10 18:54:19,616 - stpipe.Coron2Pipeline - INFO - ... ending calwebb_coron2
# [stpipe.Coron2Pipeline:INFO] ... ending calwebb_coron2
# [jwst.stpipe.core:INFO] Results used CRDS context: jwst_0928.pmap
# 2022-08-10 18:54:19,772 - stpipe.Coron2Pipeline - INFO - Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF_CLEAN/jw01386003001_03107_00001_nrcalong_calints.fits
# [stpipe.Coron2Pipeline:INFO] Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF_CLEAN/jw01386003001_03107_00001_nrcalong_calints.fits
# 2022-08-10 18:54:19,773 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline done
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline done

# %%
# Compare with no outlier correction
pipeline.meta.outlier_corr = 'none'
pipeline.imgprocess()
# Out:
# 2022-08-10 19:02:00,520 - stpipe.Coron2Pipeline - INFO - Coron2Pipeline instance created.
# --> Found 11 file(s) under: /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/
# [stpipe.Coron2Pipeline:INFO] Coron2Pipeline instance created.
# 2022-08-10 19:02:00,522 - stpipe.Coron2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# [stpipe.Coron2Pipeline.bkg_subtract:INFO] BackgroundStep instance created.
# 2022-08-10 19:02:00,523 - stpipe.Coron2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# [stpipe.Coron2Pipeline.assign_wcs:INFO] AssignWcsStep instance created.
# 2022-08-10 19:02:00,524 - stpipe.Coron2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# [stpipe.Coron2Pipeline.flat_field:INFO] FlatFieldStep instance created.
# 2022-08-10 19:02:00,525 - stpipe.Coron2Pipeline.photom - INFO - PhotomStep instance created.
# [stpipe.Coron2Pipeline.photom:INFO] PhotomStep instance created.
# 2022-08-10 19:02:00,526 - stpipe.Coron2Pipeline.resample - INFO - ResampleStep instance created.
# [stpipe.Coron2Pipeline.resample:INFO] ResampleStep instance created.
# 2022-08-10 19:02:00,528 - stpipe.Coron2Pipeline.outlier_step - INFO - OutlierDetectionStep instance created.
# [stpipe.Coron2Pipeline.outlier_step:INFO] OutlierDetectionStep instance created.
# 2022-08-10 19:02:00,529 - stpipe.Coron2Pipeline.clean_step - INFO - CleanPixStep instance created.
# [stpipe.Coron2Pipeline.clean_step:INFO] CleanPixStep instance created.
# 2022-08-10 19:02:00,687 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline running with args ('/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong_rateints.fits',).
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline running with args ('/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong_rateints.fits',).
# 2022-08-10 19:02:00,692 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'find_outliers': True, 'clean_data': False, 'clean_only': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'outlier_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'clean_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'outlier_type': '', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}}}
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'find_outliers': True, 'clean_data': False, 'clean_only': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'outlier_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'clean_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'outlier_type': '', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}}}
# 2022-08-10 19:02:00,737 - stpipe.Coron2Pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_03108_00001_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# [stpipe.Coron2Pipeline:INFO] Prefetching reference files for dataset: 'jw01386001001_03108_00001_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-08-10 19:02:00,740 - stpipe.Coron2Pipeline - INFO - Prefetch for AREA reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for AREA reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# 2022-08-10 19:02:00,741 - stpipe.Coron2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for CAMERA reference file is 'N/A'.
# 2022-08-10 19:02:00,741 - stpipe.Coron2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-08-10 19:02:00,742 - stpipe.Coron2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DFLAT reference file is 'N/A'.
# 2022-08-10 19:02:00,742 - stpipe.Coron2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DISPERSER reference file is 'N/A'.
# 2022-08-10 19:02:00,743 - stpipe.Coron2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DISTORTION reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf'.
# 2022-08-10 19:02:00,743 - stpipe.Coron2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DRIZPARS reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# 2022-08-10 19:02:00,744 - stpipe.Coron2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FFLAT reference file is 'N/A'.
# 2022-08-10 19:02:00,745 - stpipe.Coron2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FILTEROFFSET reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf'.
# 2022-08-10 19:02:00,745 - stpipe.Coron2Pipeline - INFO - Prefetch for FLAT reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FLAT reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits'.
# 2022-08-10 19:02:00,746 - stpipe.Coron2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FORE reference file is 'N/A'.
# 2022-08-10 19:02:00,746 - stpipe.Coron2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FPA reference file is 'N/A'.
# 2022-08-10 19:02:00,747 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUFORE reference file is 'N/A'.
# 2022-08-10 19:02:00,748 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUPOST reference file is 'N/A'.
# 2022-08-10 19:02:00,748 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-08-10 19:02:00,749 - stpipe.Coron2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for MSA reference file is 'N/A'.
# 2022-08-10 19:02:00,749 - stpipe.Coron2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for OTE reference file is 'N/A'.
# 2022-08-10 19:02:00,750 - stpipe.Coron2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for PHOTOM reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits'.
# 2022-08-10 19:02:00,750 - stpipe.Coron2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for REGIONS reference file is 'N/A'.
# 2022-08-10 19:02:00,751 - stpipe.Coron2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SFLAT reference file is 'N/A'.
# 2022-08-10 19:02:00,751 - stpipe.Coron2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SPECWCS reference file is 'N/A'.
# 2022-08-10 19:02:00,752 - stpipe.Coron2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-08-10 19:02:00,752 - stpipe.Coron2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-08-10 19:02:00,753 - stpipe.Coron2Pipeline - INFO - Starting calwebb_coron2 ...
# [stpipe.Coron2Pipeline:INFO] Starting calwebb_coron2 ...
# 2022-08-10 19:02:00,754 - stpipe.Coron2Pipeline - INFO - Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong
# [stpipe.Coron2Pipeline:INFO] Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong
# 2022-08-10 19:02:00,754 - stpipe.Coron2Pipeline - INFO - Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong_rateints.fits ...
# [stpipe.Coron2Pipeline:INFO] Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong_rateints.fits ...
# 2022-08-10 19:02:00,926 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# 2022-08-10 19:02:00,928 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [jwst.assign_wcs.assign_wcs_step:DEBUG] reference files used in assign_wcs: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [jwst.assign_wcs.nircam:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [jwst.assign_wcs.nircam:DEBUG] Offsets from filteroffset file are 0.0, 0.0
# [jwst.assign_wcs.util:INFO] Update S_REGION to POLYGON ICRS  209.562497407 -42.102352890 209.569569022 -42.104261422 209.572080710 -42.099077093 209.565008403 -42.097159277
# [jwst.assign_wcs.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  209.562497407 -42.102352890 209.569569022 -42.104261422 209.572080710 -42.099077093 209.565008403 -42.097159277
# [jwst.assign_wcs.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-08-10 19:02:01,174 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs done
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs done
# 2022-08-10 19:02:01,331 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# 2022-08-10 19:02:01,332 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Coron2Pipeline.flat_field:DEBUG] Input is CubeModel of exposure type NRC_CORON
# [stpipe.Coron2Pipeline.flat_field:DEBUG] Using FLAT reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type FFLAT
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type SFLAT
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type DFLAT
# [jwst.flatfield.flat_field:DEBUG] Flat field correction for non-NIRSpec modes.
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.flatfield.flat_field:INFO] Extracting matching subarray from flat
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-08-10 19:02:01,514 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field done
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field done
# 2022-08-10 19:02:01,664 - stpipe.Coron2Pipeline.photom - INFO - Step photom running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.photom:INFO] Step photom running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# 2022-08-10 19:02:01,665 - stpipe.Coron2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'inverse': False, 'source_type': None}
# [stpipe.Coron2Pipeline.photom:INFO] Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'inverse': False, 'source_type': None}
# [stpipe.Coron2Pipeline.photom:DEBUG] Input is CubeModel
# 2022-08-10 19:02:01,686 - stpipe.Coron2Pipeline.photom - INFO - Using photom reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits
# [stpipe.Coron2Pipeline.photom:INFO] Using photom reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits
# 2022-08-10 19:02:01,687 - stpipe.Coron2Pipeline.photom - INFO - Using area reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits
# [stpipe.Coron2Pipeline.photom:INFO] Using area reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits
# [jwst.photom.photom:INFO] Using instrument: NIRCAM
# [jwst.photom.photom:INFO]  detector: NRCALONG
# [jwst.photom.photom:INFO]  exp_type: NRC_CORON
# [jwst.photom.photom:INFO]  filter: F300M
# [jwst.photom.photom:INFO]  pupil: MASKRND
# [jwst.photom.photom:INFO] Pixel area map copied to output.
# [jwst.photom.photom:DEBUG] PIXAR_SR = 9.31e-14, PIXAR_A2 = 0.00396
# [jwst.photom.photom:INFO] PHOTMJSR value: 7.04474
# 2022-08-10 19:02:01,793 - stpipe.Coron2Pipeline.photom - INFO - Step photom done
# [stpipe.Coron2Pipeline.photom:INFO] Step photom done
# 2022-08-10 19:02:01,794 - stpipe.Coron2Pipeline - INFO - Finished processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong
# [stpipe.Coron2Pipeline:INFO] Finished processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00001_nrcalong
# 2022-08-10 19:02:01,927 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00001_nrcalong_rateints.fits>,).
# 2022-08-10 19:02:01,929 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2022-08-10 19:02:01,935 - stpipe.Coron2Pipeline.outlier_step - INFO - Performing outlier detection with 4 inputs
# [stpipe.Coron2Pipeline.outlier_step:INFO] Performing outlier detection with 4 inputs
# [stpipe.Coron2Pipeline.outlier_step:DEBUG] Using OutlierDetection class for outlier_detection
# [jwst.outlier_detection.outlier_detection:DEBUG] Converting CubeModel to ModelContainer with 4 images
# [jwst.outlier_detection.outlier_detection:DEBUG] Defined output product suffix as: _outlier_i2d.fits
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:INFO] Flagging outliers
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 25 (0.02%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 54 (0.05%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 27 (0.03%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 19 (0.02%)
# 2022-08-10 19:02:02,262 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step done
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step done
# 2022-08-10 19:02:02,264 - stpipe.Coron2Pipeline - INFO - ... ending calwebb_coron2
# [stpipe.Coron2Pipeline:INFO] ... ending calwebb_coron2
# [jwst.stpipe.core:INFO] Results used CRDS context: jwst_0928.pmap
# 2022-08-10 19:02:02,386 - stpipe.Coron2Pipeline - INFO - Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF/jw01386001001_03108_00001_nrcalong_calints.fits
# [stpipe.Coron2Pipeline:INFO] Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF/jw01386001001_03108_00001_nrcalong_calints.fits
# 2022-08-10 19:02:02,387 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline done
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline done
# 2022-08-10 19:02:02,549 - stpipe.Coron2Pipeline - INFO - Coron2Pipeline instance created.
# [stpipe.Coron2Pipeline:INFO] Coron2Pipeline instance created.
# 2022-08-10 19:02:02,550 - stpipe.Coron2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# [stpipe.Coron2Pipeline.bkg_subtract:INFO] BackgroundStep instance created.
# 2022-08-10 19:02:02,552 - stpipe.Coron2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# [stpipe.Coron2Pipeline.assign_wcs:INFO] AssignWcsStep instance created.
# 2022-08-10 19:02:02,553 - stpipe.Coron2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# [stpipe.Coron2Pipeline.flat_field:INFO] FlatFieldStep instance created.
# 2022-08-10 19:02:02,554 - stpipe.Coron2Pipeline.photom - INFO - PhotomStep instance created.
# [stpipe.Coron2Pipeline.photom:INFO] PhotomStep instance created.
# 2022-08-10 19:02:02,556 - stpipe.Coron2Pipeline.resample - INFO - ResampleStep instance created.
# [stpipe.Coron2Pipeline.resample:INFO] ResampleStep instance created.
# 2022-08-10 19:02:02,557 - stpipe.Coron2Pipeline.outlier_step - INFO - OutlierDetectionStep instance created.
# [stpipe.Coron2Pipeline.outlier_step:INFO] OutlierDetectionStep instance created.
# 2022-08-10 19:02:02,558 - stpipe.Coron2Pipeline.clean_step - INFO - CleanPixStep instance created.
# [stpipe.Coron2Pipeline.clean_step:INFO] CleanPixStep instance created.
# 2022-08-10 19:02:02,696 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline running with args ('/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rateints.fits',).
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline running with args ('/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rateints.fits',).
# 2022-08-10 19:02:02,700 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'find_outliers': True, 'clean_data': False, 'clean_only': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'outlier_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'clean_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'outlier_type': '', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}}}
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'find_outliers': True, 'clean_data': False, 'clean_only': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'outlier_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'clean_step': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'outlier_type': '', 'bpclean_sigclip': 5, 'bpclean_niter': 5, 'outmed_blur': 5, 'outmed_threshold': 1, 'dq_threshold': 1000, 'tmed_alt_frac': 0.2, 'custom_file': ''}}}
# 2022-08-10 19:02:02,741 - stpipe.Coron2Pipeline - INFO - Prefetching reference files for dataset: 'jw01386001001_03108_00002_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# [stpipe.Coron2Pipeline:INFO] Prefetching reference files for dataset: 'jw01386001001_03108_00002_nrcalong_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-08-10 19:02:02,745 - stpipe.Coron2Pipeline - INFO - Prefetch for AREA reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for AREA reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# 2022-08-10 19:02:02,745 - stpipe.Coron2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for CAMERA reference file is 'N/A'.
# 2022-08-10 19:02:02,746 - stpipe.Coron2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-08-10 19:02:02,747 - stpipe.Coron2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DFLAT reference file is 'N/A'.
# 2022-08-10 19:02:02,747 - stpipe.Coron2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DISPERSER reference file is 'N/A'.
# 2022-08-10 19:02:02,748 - stpipe.Coron2Pipeline - INFO - Prefetch for DISTORTION reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DISTORTION reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf'.
# 2022-08-10 19:02:02,748 - stpipe.Coron2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for DRIZPARS reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# 2022-08-10 19:02:02,749 - stpipe.Coron2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FFLAT reference file is 'N/A'.
# 2022-08-10 19:02:02,749 - stpipe.Coron2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FILTEROFFSET reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf'.
# 2022-08-10 19:02:02,750 - stpipe.Coron2Pipeline - INFO - Prefetch for FLAT reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FLAT reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits'.
# 2022-08-10 19:02:02,751 - stpipe.Coron2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FORE reference file is 'N/A'.
# 2022-08-10 19:02:02,751 - stpipe.Coron2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FPA reference file is 'N/A'.
# 2022-08-10 19:02:02,752 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUFORE reference file is 'N/A'.
# 2022-08-10 19:02:02,752 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUPOST reference file is 'N/A'.
# 2022-08-10 19:02:02,753 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-08-10 19:02:02,753 - stpipe.Coron2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for MSA reference file is 'N/A'.
# 2022-08-10 19:02:02,754 - stpipe.Coron2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for OTE reference file is 'N/A'.
# 2022-08-10 19:02:02,755 - stpipe.Coron2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for PHOTOM reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits'.
# 2022-08-10 19:02:02,755 - stpipe.Coron2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for REGIONS reference file is 'N/A'.
# 2022-08-10 19:02:02,756 - stpipe.Coron2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SFLAT reference file is 'N/A'.
# 2022-08-10 19:02:02,756 - stpipe.Coron2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SPECWCS reference file is 'N/A'.
# 2022-08-10 19:02:02,757 - stpipe.Coron2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-08-10 19:02:02,757 - stpipe.Coron2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-08-10 19:02:02,758 - stpipe.Coron2Pipeline - INFO - Starting calwebb_coron2 ...
# [stpipe.Coron2Pipeline:INFO] Starting calwebb_coron2 ...
# 2022-08-10 19:02:02,758 - stpipe.Coron2Pipeline - INFO - Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong
# [stpipe.Coron2Pipeline:INFO] Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong
# 2022-08-10 19:02:02,759 - stpipe.Coron2Pipeline - INFO - Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rateints.fits ...
# [stpipe.Coron2Pipeline:INFO] Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386001001_03108_00002_nrcalong_rateints.fits ...
# 2022-08-10 19:02:02,936 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00002_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00002_nrcalong_rateints.fits>,).
# 2022-08-10 19:02:02,937 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [jwst.assign_wcs.assign_wcs_step:DEBUG] reference files used in assign_wcs: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [jwst.assign_wcs.nircam:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [jwst.assign_wcs.nircam:DEBUG] Offsets from filteroffset file are 0.0, 0.0
# [jwst.assign_wcs.util:INFO] Update S_REGION to POLYGON ICRS  209.562490330 -42.102350955 209.569561946 -42.104259484 209.572073631 -42.099075155 209.565001323 -42.097157341
# [jwst.assign_wcs.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  209.562490330 -42.102350955 209.569561946 -42.104259484 209.572073631 -42.099075155 209.565001323 -42.097157341
# [jwst.assign_wcs.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-08-10 19:02:03,178 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs done
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs done
# 2022-08-10 19:02:03,314 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00002_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field running with args (<CubeModel(4, 320, 320) from jw01386001001_03108_00002_nrcalong_rateints.fits>,).
# 2022-08-10 19:02:03,315 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# ...
# [stpipe.Coron2Pipeline:INFO] Prefetch for FLAT reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits'.
# 2022-08-10 19:02:20,641 - stpipe.Coron2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FORE reference file is 'N/A'.
# 2022-08-10 19:02:20,642 - stpipe.Coron2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for FPA reference file is 'N/A'.
# 2022-08-10 19:02:20,642 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUFORE reference file is 'N/A'.
# 2022-08-10 19:02:20,643 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUPOST reference file is 'N/A'.
# 2022-08-10 19:02:20,644 - stpipe.Coron2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-08-10 19:02:20,644 - stpipe.Coron2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for MSA reference file is 'N/A'.
# 2022-08-10 19:02:20,645 - stpipe.Coron2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for OTE reference file is 'N/A'.
# 2022-08-10 19:02:20,645 - stpipe.Coron2Pipeline - INFO - Prefetch for PHOTOM reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for PHOTOM reference file is '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits'.
# 2022-08-10 19:02:20,646 - stpipe.Coron2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for REGIONS reference file is 'N/A'.
# 2022-08-10 19:02:20,647 - stpipe.Coron2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SFLAT reference file is 'N/A'.
# 2022-08-10 19:02:20,647 - stpipe.Coron2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for SPECWCS reference file is 'N/A'.
# 2022-08-10 19:02:20,648 - stpipe.Coron2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-08-10 19:02:20,648 - stpipe.Coron2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# [stpipe.Coron2Pipeline:INFO] Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-08-10 19:02:20,649 - stpipe.Coron2Pipeline - INFO - Starting calwebb_coron2 ...
# [stpipe.Coron2Pipeline:INFO] Starting calwebb_coron2 ...
# 2022-08-10 19:02:20,650 - stpipe.Coron2Pipeline - INFO - Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong
# [stpipe.Coron2Pipeline:INFO] Processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong
# 2022-08-10 19:02:20,650 - stpipe.Coron2Pipeline - INFO - Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong_rateints.fits ...
# [stpipe.Coron2Pipeline:INFO] Working on input /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong_rateints.fits ...
# 2022-08-10 19:02:20,827 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# 2022-08-10 19:02:20,828 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [jwst.assign_wcs.assign_wcs_step:DEBUG] reference files used in assign_wcs: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [jwst.assign_wcs.nircam:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_distortion_0129.asdf', 'filteroffset': '/home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_filteroffset_0008.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [jwst.assign_wcs.nircam:DEBUG] Offsets from filteroffset file are 0.0, 0.0
# [jwst.assign_wcs.util:INFO] Update S_REGION to POLYGON ICRS  201.143692896 -51.505350264 201.151434275 -51.508170525 201.155876000 -51.503405313 201.148136480 -51.500575900
# [jwst.assign_wcs.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  201.143692896 -51.505350264 201.151434275 -51.508170525 201.155876000 -51.503405313 201.148136480 -51.500575900
# [jwst.assign_wcs.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-08-10 19:02:21,123 - stpipe.Coron2Pipeline.assign_wcs - INFO - Step assign_wcs done
# [stpipe.Coron2Pipeline.assign_wcs:INFO] Step assign_wcs done
# 2022-08-10 19:02:21,261 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# 2022-08-10 19:02:21,262 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Coron2Pipeline.flat_field:DEBUG] Input is CubeModel of exposure type NRC_CORON
# [stpipe.Coron2Pipeline.flat_field:DEBUG] Using FLAT reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_flat_0464.fits
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type FFLAT
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type SFLAT
# [stpipe.Coron2Pipeline.flat_field:DEBUG] No reference found for type DFLAT
# [jwst.flatfield.flat_field:DEBUG] Flat field correction for non-NIRSpec modes.
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.flatfield.flat_field:INFO] Extracting matching subarray from flat
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-08-10 19:02:21,433 - stpipe.Coron2Pipeline.flat_field - INFO - Step flat_field done
# [stpipe.Coron2Pipeline.flat_field:INFO] Step flat_field done
# 2022-08-10 19:02:21,569 - stpipe.Coron2Pipeline.photom - INFO - Step photom running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.photom:INFO] Step photom running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# 2022-08-10 19:02:21,571 - stpipe.Coron2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'inverse': False, 'source_type': None}
# [stpipe.Coron2Pipeline.photom:INFO] Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'inverse': False, 'source_type': None}
# [stpipe.Coron2Pipeline.photom:DEBUG] Input is CubeModel
# 2022-08-10 19:02:21,591 - stpipe.Coron2Pipeline.photom - INFO - Using photom reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits
# [stpipe.Coron2Pipeline.photom:INFO] Using photom reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_photom_0104.fits
# 2022-08-10 19:02:21,592 - stpipe.Coron2Pipeline.photom - INFO - Using area reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits
# [stpipe.Coron2Pipeline.photom:INFO] Using area reference file: /home/jarronl/NIRCam/crds_cache/jwst_pub/references/jwst/nircam/jwst_nircam_area_0014.fits
# [jwst.photom.photom:INFO] Using instrument: NIRCAM
# [jwst.photom.photom:INFO]  detector: NRCALONG
# [jwst.photom.photom:INFO]  exp_type: NRC_CORON
# [jwst.photom.photom:INFO]  filter: F300M
# [jwst.photom.photom:INFO]  pupil: MASKRND
# [jwst.photom.photom:INFO] Pixel area map copied to output.
# [jwst.photom.photom:DEBUG] PIXAR_SR = 9.31e-14, PIXAR_A2 = 0.00396
# [jwst.photom.photom:INFO] PHOTMJSR value: 7.04474
# 2022-08-10 19:02:21,699 - stpipe.Coron2Pipeline.photom - INFO - Step photom done
# [stpipe.Coron2Pipeline.photom:INFO] Step photom done
# 2022-08-10 19:02:21,699 - stpipe.Coron2Pipeline - INFO - Finished processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong
# [stpipe.Coron2Pipeline:INFO] Finished processing product /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF/jw01386003001_03107_00001_nrcalong
# 2022-08-10 19:02:21,837 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step running with args (<CubeModel(4, 320, 320) from jw01386003001_03107_00001_nrcalong_rateints.fits>,).
# 2022-08-10 19:02:21,839 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/RAMPFIT/SCI+REF', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2022-08-10 19:02:21,845 - stpipe.Coron2Pipeline.outlier_step - INFO - Performing outlier detection with 4 inputs
# [stpipe.Coron2Pipeline.outlier_step:INFO] Performing outlier detection with 4 inputs
# [stpipe.Coron2Pipeline.outlier_step:DEBUG] Using OutlierDetection class for outlier_detection
# [jwst.outlier_detection.outlier_detection:DEBUG] Converting CubeModel to ModelContainer with 4 images
# [jwst.outlier_detection.outlier_detection:DEBUG] Defined output product suffix as: _outlier_i2d.fits
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:DEBUG] Percentage of pixels with low weight: 0.3212890625
# [jwst.outlier_detection.outlier_detection:INFO] Flagging outliers
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 57 (0.06%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 21 (0.02%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 12 (0.01%)
# [jwst.outlier_detection.outlier_detection:INFO] New pixels flagged as outliers: 23 (0.02%)
# 2022-08-10 19:02:22,162 - stpipe.Coron2Pipeline.outlier_step - INFO - Step outlier_step done
# [stpipe.Coron2Pipeline.outlier_step:INFO] Step outlier_step done
# 2022-08-10 19:02:22,163 - stpipe.Coron2Pipeline - INFO - ... ending calwebb_coron2
# [stpipe.Coron2Pipeline:INFO] ... ending calwebb_coron2
# [jwst.stpipe.core:INFO] Results used CRDS context: jwst_0928.pmap
# 2022-08-10 19:02:22,281 - stpipe.Coron2Pipeline - INFO - Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF/jw01386003001_03107_00001_nrcalong_calints.fits
# [stpipe.Coron2Pipeline:INFO] Saved model in /data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF/jw01386003001_03107_00001_nrcalong_calints.fits
# 2022-08-10 19:02:22,282 - stpipe.Coron2Pipeline - INFO - Step Coron2Pipeline done
# [stpipe.Coron2Pipeline:INFO] Step Coron2Pipeline done

# %%
p1 = '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF/'
p2 = '/data/NIRData/MAST_proc/01386/HIP65426/F300M_MASK335R/IMGPROCESS/SCI+REF_CLEAN/'
f = 'jw01386003001_03107_00001_nrcalong_calints.fits'
hdul1 = fits.open(p1+f)
hdul2 = fits.open(p2+f)

# %%
fig, axes = plt.subplots(1,2, figsize=(14,7))

im = hdul1[1].data[0]

med = np.nanmedian(im)
std = robust.medabsdev(im)
vmin = med - 5*std
vmax = med + 5*std

ax = axes[0]
ax.imshow(im, vmin=vmin, vmax=vmax)


im = hdul2[1].data[0]

med = np.nanmedian(im)
std = robust.medabsdev(im)
vmin = med - 5*std
vmax = med + 5*std

ax = axes[1]
ax.imshow(im, vmin=vmin, vmax=vmax)


fig.tight_layout()

# %%
# Perform PSF Subtraction
pipeline.subtraction()

# %%
# Compute raw contrast
pipeline.raw_contrast()

# %%
# Compute calibrated contrast
pipeline.cal_contrast()

# %%
# Extract companion photometry and astrometry
pipeline.companion()
