# %%
# Append the directory of the spaceKLIP install, shouldn't be necessary if installed in your conda environment

import os, sys
sys.path.append('../')

# Import the JWST class from spaceKLIP
from spaceKLIP.engine import JWST
# Out:
# **WARNING**: LOCAL JWST PRD VERSION PRDOPSSOC-044 DOESN'T MATCH THE CURRENT ONLINE VERSION PRDOPSSOC-045
# Please consider updating pysiaf, e.g. pip install --upgrade pysiaf or conda update pysiaf

# %%
# Provide config file, or 'template' to use existing template
config_file = 'template'
pipeline = JWST(config_file)

# %%
# Perform ramp fitting
pipeline.rampfit()
# Out:
# 2022-04-22 15:29:49,126 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# [stpipe.Detector1Pipeline:INFO] Detector1Pipeline instance created.
# 2022-04-22 15:29:49,128 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# [stpipe.Detector1Pipeline.group_scale:INFO] GroupScaleStep instance created.
# 2022-04-22 15:29:49,130 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# [stpipe.Detector1Pipeline.dq_init:INFO] DQInitStep instance created.
# 2022-04-22 15:29:49,132 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# [stpipe.Detector1Pipeline.saturation:INFO] SaturationStep instance created.
# 2022-04-22 15:29:49,135 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# [stpipe.Detector1Pipeline.ipc:INFO] IPCStep instance created.
# 2022-04-22 15:29:49,137 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# [stpipe.Detector1Pipeline.superbias:INFO] SuperBiasStep instance created.
# 2022-04-22 15:29:49,140 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# [stpipe.Detector1Pipeline.refpix:INFO] RefPixStep instance created.
# 2022-04-22 15:29:49,143 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# [stpipe.Detector1Pipeline.rscd:INFO] RscdStep instance created.
# 2022-04-22 15:29:49,146 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# [stpipe.Detector1Pipeline.firstframe:INFO] FirstFrameStep instance created.
# 2022-04-22 15:29:49,149 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# [stpipe.Detector1Pipeline.lastframe:INFO] LastFrameStep instance created.
# 2022-04-22 15:29:49,152 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# [stpipe.Detector1Pipeline.linearity:INFO] LinearityStep instance created.
# 2022-04-22 15:29:49,155 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# [stpipe.Detector1Pipeline.dark_current:INFO] DarkCurrentStep instance created.
# 2022-04-22 15:29:49,158 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# [stpipe.Detector1Pipeline.reset:INFO] ResetStep instance created.
# 2022-04-22 15:29:49,162 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# [stpipe.Detector1Pipeline.persistence:INFO] PersistenceStep instance created.
# 2022-04-22 15:29:49,166 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# [stpipe.Detector1Pipeline.jump:INFO] JumpStep instance created.
# 2022-04-22 15:29:49,168 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# [stpipe.Detector1Pipeline.ramp_fit:INFO] RampFitStep instance created.
# 2022-04-22 15:29:49,171 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# [stpipe.Detector1Pipeline.gain_scale:INFO] GainScaleStep instance created.
# 2022-04-22 15:29:49,256 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal/pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits',).
# [stpipe.Detector1Pipeline:INFO] Step Detector1Pipeline running with args ('/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal/pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits',).
# 2022-04-22 15:29:49,270 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': Fals ...
# [stpipe.Detector1Pipeline:INFO] Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix':  ...
# 2022-04-22 15:29:50,353 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# [stpipe.Detector1Pipeline:INFO] Prefetching reference files for dataset: 'pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits' reftypes = ['dark', 'gain', 'ipc', 'linearity', 'mask', 'persat', 'readnoise', 'refpix', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2022-04-22 15:29:51,610 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_dark_0281.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for DARK reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_dark_0281.fits'.
# 2022-04-22 15:29:51,611 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_gain_0056.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for GAIN reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_gain_0056.fits'.
# 2022-04-22 15:29:51,613 - stpipe.Detector1Pipeline - INFO - Prefetch for IPC reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0028.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for IPC reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0028.fits'.
# 2022-04-22 15:29:51,615 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0052.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for LINEARITY reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0052.fits'.
# 2022-04-22 15:29:51,617 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_mask_0052.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for MASK reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_mask_0052.fits'.
# 2022-04-22 15:29:51,619 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_persat_0021.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for PERSAT reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_persat_0021.fits'.
# 2022-04-22 15:29:51,620 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0038.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for READNOISE reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0038.fits'.
# 2022-04-22 15:29:51,622 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for REFPIX reference file is 'N/A'.
# 2022-04-22 15:29:51,623 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is 'N/A'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for RESET reference file is 'N/A'.
# 2022-04-22 15:29:51,625 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is 'N/A'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for RSCD reference file is 'N/A'.
# 2022-04-22 15:29:51,626 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0091.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for SATURATION reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0091.fits'.
# 2022-04-22 15:29:51,628 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0022.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for SUPERBIAS reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0022.fits'.
# 2022-04-22 15:29:51,629 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_trapdensity_0004.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for TRAPDENSITY reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_trapdensity_0004.fits'.
# 2022-04-22 15:29:51,630 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_trappars_0002.fits'.
# [stpipe.Detector1Pipeline:INFO] Prefetch for TRAPPARS reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_trappars_0002.fits'.
# [jwst.pipeline.calwebb_detector1:INFO] Starting calwebb_detector1 ...
# 2022-04-22 15:29:51,631 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# [stpipe.Detector1Pipeline:INFO] Starting calwebb_detector1 ...
# [jwst.pipeline.calwebb_detector1:DEBUG] Processing a Near-IR exposure
# [stpipe.Detector1Pipeline:DEBUG] Processing a Near-IR exposure
# 2022-04-22 15:29:51,915 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.group_scale:INFO] Step group_scale running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# 2022-04-22 15:29:51,917 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# [stpipe.Detector1Pipeline.group_scale:INFO] Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# 2022-04-22 15:29:51,977 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# [stpipe.Detector1Pipeline.group_scale:INFO] NFRAMES and FRMDIVSR are equal; correction not needed
# 2022-04-22 15:29:51,979 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# [stpipe.Detector1Pipeline.group_scale:INFO] Step will be skipped
# 2022-04-22 15:29:51,983 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# [stpipe.Detector1Pipeline.group_scale:INFO] Step group_scale done
# 2022-04-22 15:29:52,071 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.dq_init:INFO] Step dq_init running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# 2022-04-22 15:29:52,073 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# [stpipe.Detector1Pipeline.dq_init:INFO] Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# 2022-04-22 15:29:52,101 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_mask_0052.fits
# [stpipe.Detector1Pipeline.dq_init:INFO] Using MASK reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_mask_0052.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Detector1Pipeline.dq_init:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Detector1Pipeline.dq_init:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.dq_init.dq_initialization:INFO] Extracting mask subarray to match science data
# 2022-04-22 15:29:52,666 - stpipe.Detector1Pipeline.dq_init - INFO - Extracting mask subarray to match science data
# [stpipe.Detector1Pipeline.dq_init:INFO] Extracting mask subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Detector1Pipeline.dq_init:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-04-22 15:29:52,688 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# [stpipe.Detector1Pipeline.dq_init:INFO] Step dq_init done
# 2022-04-22 15:29:52,779 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.saturation:INFO] Step saturation running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# 2022-04-22 15:29:52,781 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# [stpipe.Detector1Pipeline.saturation:INFO] Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# 2022-04-22 15:29:52,810 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0091.fits
# [stpipe.Detector1Pipeline.saturation:INFO] Using SATURATION reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_saturation_0091.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Detector1Pipeline.saturation:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Detector1Pipeline.saturation:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.saturation.saturation:INFO] Extracting reference file subarray to match science data
# 2022-04-22 15:29:53,355 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# [stpipe.Detector1Pipeline.saturation:INFO] Extracting reference file subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Detector1Pipeline.saturation:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stcal.saturation.saturation:INFO] Detected 139 saturated pixels
# 2022-04-22 15:29:53,378 - stpipe.Detector1Pipeline.saturation - INFO - Detected 139 saturated pixels
# [stpipe.Detector1Pipeline.saturation:INFO] Detected 139 saturated pixels
# [stcal.saturation.saturation:INFO] Detected 0 A/D floor pixels
# 2022-04-22 15:29:53,380 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# [stpipe.Detector1Pipeline.saturation:INFO] Detected 0 A/D floor pixels
# 2022-04-22 15:29:53,391 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# [stpipe.Detector1Pipeline.saturation:INFO] Step saturation done
# 2022-04-22 15:29:53,480 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.ipc:INFO] Step ipc running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# 2022-04-22 15:29:53,483 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# [stpipe.Detector1Pipeline.ipc:INFO] Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# 2022-04-22 15:29:53,512 - stpipe.Detector1Pipeline.ipc - INFO - Using IPC reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0028.fits
# [stpipe.Detector1Pipeline.ipc:INFO] Using IPC reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_ipc_0028.fits
# [jwst.ipc.ipc_corr:DEBUG] IPC corr using nints=2, ngroups=4, nframes=8, groupgap=2
# [stpipe.Detector1Pipeline.ipc:DEBUG] IPC corr using nints=2, ngroups=4, nframes=8, groupgap=2
# [jwst.ipc.ipc_corr:DEBUG] ipc_correction: nints=2, ngroups=4, size=320,320
# [stpipe.Detector1Pipeline.ipc:DEBUG] ipc_correction: nints=2, ngroups=4, size=320,320
# [jwst.ipc.ipc_corr:DEBUG] substrt1 = 492, subsize1 = 320, substrt2 = 1502, subsize2 = 320
# [stpipe.Detector1Pipeline.ipc:DEBUG] substrt1 = 492, subsize1 = 320, substrt2 = 1502, subsize2 = 320
# [jwst.ipc.ipc_corr:DEBUG] Number of reference pixels: bottom, top, left, right = 0, 0, 0, 0
# [stpipe.Detector1Pipeline.ipc:DEBUG] Number of reference pixels: bottom, top, left, right = 0, 0, 0, 0
# [jwst.ipc.ipc_corr:DEBUG] Shape of ipc image = (3, 3)
# [stpipe.Detector1Pipeline.ipc:DEBUG] Shape of ipc image = (3, 3)
# 2022-04-22 15:29:53,604 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# [stpipe.Detector1Pipeline.ipc:INFO] Step ipc done
# 2022-04-22 15:29:53,696 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.superbias:INFO] Step superbias running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# 2022-04-22 15:29:53,698 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# [stpipe.Detector1Pipeline.superbias:INFO] Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# 2022-04-22 15:29:53,732 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0022.fits
# [stpipe.Detector1Pipeline.superbias:INFO] Using SUPERBIAS reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_superbias_0022.fits
# [stcal.dynamicdq:WARNING] Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-22 15:29:53,916 - stpipe.Detector1Pipeline.superbias - WARNING - Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# [stpipe.Detector1Pipeline.superbias:WARNING] Keyword NOISY does not correspond to an existing DQ mnemonic, so will be ignored
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Detector1Pipeline.superbias:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Detector1Pipeline.superbias:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Detector1Pipeline.superbias:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-04-22 15:29:53,997 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# [stpipe.Detector1Pipeline.superbias:INFO] Step superbias done
# 2022-04-22 15:29:54,087 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.refpix:INFO] Step refpix running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# 2022-04-22 15:29:54,089 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# [stpipe.Detector1Pipeline.refpix:INFO] Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2022-04-22 15:29:54,102 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# [stpipe.Detector1Pipeline.refpix:INFO] use_side_ref_pixels = True
# 2022-04-22 15:29:54,104 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# [stpipe.Detector1Pipeline.refpix:INFO] odd_even_columns = True
# 2022-04-22 15:29:54,105 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# [stpipe.Detector1Pipeline.refpix:INFO] side_smoothing_length = 11
# 2022-04-22 15:29:54,105 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.0
# [stpipe.Detector1Pipeline.refpix:INFO] side_gain = 1.0
# 2022-04-22 15:29:54,106 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = True
# [stpipe.Detector1Pipeline.refpix:INFO] odd_even_rows = True
# [jwst.lib.reffile_utils:DEBUG] Input exposure is a subarray readout
# [stpipe.Detector1Pipeline.refpix:DEBUG] Input exposure is a subarray readout
# [jwst.lib.reffile_utils:DEBUG] Input exposure is a subarray readout
# [stpipe.Detector1Pipeline.refpix:DEBUG] Input exposure is a subarray readout
# 2022-04-22 15:29:54,190 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# [stpipe.Detector1Pipeline.refpix:INFO] Step refpix done
# 2022-04-22 15:29:54,275 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.linearity:INFO] Step linearity running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# 2022-04-22 15:29:54,278 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# [stpipe.Detector1Pipeline.linearity:INFO] Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# 2022-04-22 15:29:54,307 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0052.fits
# [stpipe.Detector1Pipeline.linearity:INFO] Using Linearity reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_linearity_0052.fits
# [stcal.dynamicdq:WARNING] Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-22 15:29:54,451 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# [stpipe.Detector1Pipeline.linearity:WARNING] Keyword UAZ_DO_NOT_USE does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-22 15:29:54,454 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# [stpipe.Detector1Pipeline.linearity:WARNING] Keyword UAZ_NO_LIN_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-22 15:29:54,456 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# [stpipe.Detector1Pipeline.linearity:WARNING] Keyword UAZ_BAD_LIN_FIT does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-22 15:29:54,458 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# [stpipe.Detector1Pipeline.linearity:WARNING] Keyword UAZ_NO_WELL_SAMP does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-22 15:29:54,460 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# [stpipe.Detector1Pipeline.linearity:WARNING] Keyword UAZ_MODEL_FIT_FAIL does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-22 15:29:54,462 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# [stpipe.Detector1Pipeline.linearity:WARNING] Keyword UAZ_WELL_NOT_DEFINED does not correspond to an existing DQ mnemonic, so will be ignored
# [stcal.dynamicdq:WARNING] Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-22 15:29:54,463 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# [stpipe.Detector1Pipeline.linearity:WARNING] Keyword UAZ_MASTER_MASK does not correspond to an existing DQ mnemonic, so will be ignored
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Detector1Pipeline.linearity:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Detector1Pipeline.linearity:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Detector1Pipeline.linearity:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-04-22 15:29:54,553 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# [stpipe.Detector1Pipeline.linearity:INFO] Step linearity done
# 2022-04-22 15:29:54,647 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.persistence:INFO] Step persistence running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# 2022-04-22 15:29:54,649 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}
# [stpipe.Detector1Pipeline.persistence:INFO] Step persistence parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal', 'input_trapsfilled': '', 'flag_pers_cutoff': 40.0, 'save_persistence': False, 'save_trapsfilled': True}
# [stcal.dynamicdq:WARNING] Keyword WEIRD does not correspond to an existing DQ mnemonic, so will be ignored
# 2022-04-22 15:29:54,886 - stpipe.Detector1Pipeline.persistence - WARNING - Keyword WEIRD does not correspond to an existing DQ mnemonic, so will be ignored
# [stpipe.Detector1Pipeline.persistence:WARNING] Keyword WEIRD does not correspond to an existing DQ mnemonic, so will be ignored
# [jwst.persistence.persistence:DEBUG] input_traps_filled = None
# [stpipe.Detector1Pipeline.persistence:DEBUG] input_traps_filled = None
# [jwst.persistence.persistence:DEBUG] flag_pers_cutoff = 40
# [stpipe.Detector1Pipeline.persistence:DEBUG] flag_pers_cutoff = 40
# [jwst.persistence.persistence:DEBUG] save_persistence = False
# [stpipe.Detector1Pipeline.persistence:DEBUG] save_persistence = False
# [jwst.persistence.persistence:DEBUG] The input is a subarray.
# [stpipe.Detector1Pipeline.persistence:DEBUG] The input is a subarray.
# 2022-04-22 15:29:55,556 - stpipe.Detector1Pipeline.persistence - INFO - Saved model in /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00006_nrca5_trapsfilled.fits
# [stpipe.Detector1Pipeline.persistence:INFO] Saved model in /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00006_nrca5_trapsfilled.fits
# 2022-04-22 15:29:55,566 - stpipe.Detector1Pipeline.persistence - INFO - Step persistence done
# [stpipe.Detector1Pipeline.persistence:INFO] Step persistence done
# 2022-04-22 15:29:55,666 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.dark_current:INFO] Step dark_current running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# 2022-04-22 15:29:55,668 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal', 'dark_output': None}
# [stpipe.Detector1Pipeline.dark_current:INFO] Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal', 'dark_output': None}
# 2022-04-22 15:29:55,697 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_dark_0281.fits
# [stpipe.Detector1Pipeline.dark_current:INFO] Using DARK reference file /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_dark_0281.fits
# [stcal.dark_current.dark_sub:INFO] Science data nints=2, ngroups=4, nframes=8, groupgap=2
# 2022-04-22 15:29:55,919 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=2, ngroups=4, nframes=8, groupgap=2
# [stpipe.Detector1Pipeline.dark_current:INFO] Science data nints=2, ngroups=4, nframes=8, groupgap=2
# [stcal.dark_current.dark_sub:INFO] Dark data nints=1, ngroups=400, nframes=1, groupgap=0
# 2022-04-22 15:29:55,920 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=400, nframes=1, groupgap=0
# [stpipe.Detector1Pipeline.dark_current:INFO] Dark data nints=1, ngroups=400, nframes=1, groupgap=0
# [stcal.dark_current.dark_sub:DEBUG] average dark frames 1 to 8
# [stpipe.Detector1Pipeline.dark_current:DEBUG] average dark frames 1 to 8
# [stcal.dark_current.dark_sub:DEBUG] average dark frames 11 to 18
# [stpipe.Detector1Pipeline.dark_current:DEBUG] average dark frames 11 to 18
# [stcal.dark_current.dark_sub:DEBUG] average dark frames 21 to 28
# [stpipe.Detector1Pipeline.dark_current:DEBUG] average dark frames 21 to 28
# [stcal.dark_current.dark_sub:DEBUG] average dark frames 31 to 38
# [stpipe.Detector1Pipeline.dark_current:DEBUG] average dark frames 31 to 38
# [stcal.dark_current.dark_sub:DEBUG] subtract_dark: nints=2, ngroups=4, size=320,320
# [stpipe.Detector1Pipeline.dark_current:DEBUG] subtract_dark: nints=2, ngroups=4, size=320,320
# 2022-04-22 15:29:56,031 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# [stpipe.Detector1Pipeline.dark_current:INFO] Step dark_current done
# 2022-04-22 15:29:56,135 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.jump:INFO] Step jump running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00006_nrca5_uncal.fits>,).
# 2022-04-22 15:29:56,137 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal', 'rejection_threshold': 20, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0}
# [stpipe.Detector1Pipeline.jump:INFO] Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal', 'rejection_threshold': 20, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0}
# 2022-04-22 15:29:56,156 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 20 sigma
# [stpipe.Detector1Pipeline.jump:INFO] CR rejection threshold = 20 sigma
# 2022-04-22 15:29:56,174 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_gain_0056.fits
# [stpipe.Detector1Pipeline.jump:INFO] Using GAIN reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_gain_0056.fits
# 2022-04-22 15:29:56,246 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0038.fits
# [stpipe.Detector1Pipeline.jump:INFO] Using READNOISE reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0038.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Detector1Pipeline.jump:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Detector1Pipeline.jump:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.jump.jump:INFO] Extracting gain subarray to match science data
# 2022-04-22 15:29:56,325 - stpipe.Detector1Pipeline.jump - INFO - Extracting gain subarray to match science data
# [stpipe.Detector1Pipeline.jump:INFO] Extracting gain subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [stpipe.Detector1Pipeline.jump:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [jwst.lib.reffile_utils:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [stpipe.Detector1Pipeline.jump:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Detector1Pipeline.jump:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Detector1Pipeline.jump:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Detector1Pipeline.jump:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.jump.jump:INFO] Extracting readnoise subarray to match science data
# 2022-04-22 15:29:56,333 - stpipe.Detector1Pipeline.jump - INFO - Extracting readnoise subarray to match science data
# [stpipe.Detector1Pipeline.jump:INFO] Extracting readnoise subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [stpipe.Detector1Pipeline.jump:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [jwst.lib.reffile_utils:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [stpipe.Detector1Pipeline.jump:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Detector1Pipeline.jump:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stcal.jump.jump:INFO] Executing two-point difference method
# 2022-04-22 15:29:56,339 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# [stpipe.Detector1Pipeline.jump:INFO] Executing two-point difference method
# [stcal.jump.twopoint_difference:INFO] Working on integration 1:
# 2022-04-22 15:29:56,341 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# ...
#   max_ratio = np.nanmax(ratio, axis=0)
#
# 2022-04-22 15:31:03,862 - stpipe.Detector1Pipeline.jump - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:121: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
#
# [stpipe.Detector1Pipeline.jump:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/stcal/jump/twopoint_difference.py:121: RuntimeWarning: All-NaN slice encountered
#   max_ratio = np.nanmax(ratio, axis=0)
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# 2022-04-22 15:31:03,865 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stpipe.Detector1Pipeline.jump:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 65 pixels with at least one CR from four groups.
# 2022-04-22 15:31:03,867 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 65 pixels with at least one CR from four groups.
# [stpipe.Detector1Pipeline.jump:INFO] From highest outlier, two-point found 65 pixels with at least one CR from four groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-04-22 15:31:03,868 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stpipe.Detector1Pipeline.jump:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stcal.jump.twopoint_difference:INFO] Working on integration 2:
# 2022-04-22 15:31:03,884 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# [stpipe.Detector1Pipeline.jump:INFO] Working on integration 2:
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# 2022-04-22 15:31:03,909 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stpipe.Detector1Pipeline.jump:INFO] From highest outlier, two-point found 0 pixels with at least one CR from five groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 76 pixels with at least one CR from four groups.
# 2022-04-22 15:31:03,911 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 76 pixels with at least one CR from four groups.
# [stpipe.Detector1Pipeline.jump:INFO] From highest outlier, two-point found 76 pixels with at least one CR from four groups.
# [stcal.jump.twopoint_difference:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# 2022-04-22 15:31:03,912 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stpipe.Detector1Pipeline.jump:INFO] From highest outlier, two-point found 0 pixels with at least one CR from three groups.
# [stcal.jump.jump:INFO] Total elapsed time = 0.0945463 sec
# 2022-04-22 15:31:03,930 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 0.0945463 sec
# [stpipe.Detector1Pipeline.jump:INFO] Total elapsed time = 0.0945463 sec
# 2022-04-22 15:31:03,934 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 0.278324
# [stpipe.Detector1Pipeline.jump:INFO] The execution time in seconds: 0.278324
# 2022-04-22 15:31:03,943 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# [stpipe.Detector1Pipeline.jump:INFO] Step jump done
# 2022-04-22 15:31:04,052 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00001_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Step ramp_fit running with args (<RampModel(2, 4, 320, 320) from pynrc_jw01386001001_0310A_00001_nrca5_uncal.fits>,).
# 2022-04-22 15:31:04,054 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal', 'int_name': '', 'save_opt': False, 'opt_name': '', 'maximum_cores': 'none'}
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal', 'int_name': '', 'save_opt': False, 'opt_name': '', 'maximum_cores': 'none'}
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using READNOISE reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0038.fits
# 2022-04-22 15:31:04,101 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0038.fits
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Using READNOISE reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_readnoise_0038.fits
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using GAIN reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_gain_0056.fits
# 2022-04-22 15:31:04,103 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_gain_0056.fits
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Using GAIN reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_gain_0056.fits
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.ramp_fitting.ramp_fit_step:INFO] Extracting gain subarray to match science data
# 2022-04-22 15:31:04,192 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting gain subarray to match science data
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Extracting gain subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [jwst.lib.reffile_utils:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.ramp_fitting.ramp_fit_step:INFO] Extracting readnoise subarray to match science data
# 2022-04-22 15:31:04,199 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting readnoise subarray to match science data
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Extracting readnoise subarray to match science data
# [jwst.lib.reffile_utils:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] science xstart=492, xsize=320, ystart=1502, ysize=320
# [jwst.lib.reffile_utils:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] reference xstart=1, xsize=2048, ystart=1, ysize=2048
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using algorithm = ols
# 2022-04-22 15:31:04,202 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Using algorithm = ols
# [jwst.ramp_fitting.ramp_fit_step:INFO] Using weighting = optimal
# 2022-04-22 15:31:04,204 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Using weighting = optimal
# [stcal.ramp_fitting.ols_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] Missing keyword DRPFRMS1, so setting to default value of 0
# [stcal.ramp_fitting.utils:DEBUG] The number of pixels having insufficient data
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] The number of pixels having insufficient data
# [stcal.ramp_fitting.utils:DEBUG] due to excessive CRs or saturation 139:
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] due to excessive CRs or saturation 139:
# [stcal.ramp_fitting.utils:DEBUG] Count rates - min, mean, max, std: -229.556168, -0.018674, 313.696716, 5.373800
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] Count rates - min, mean, max, std: -229.556168, -0.018674, 313.696716, 5.373800
# [stcal.ramp_fitting.ols_fit:DEBUG] Instrument: NIRCAM
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] Instrument: NIRCAM
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of pixels in 2D array: 102400
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] Number of pixels in 2D array: 102400
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of 2D image: (320, 320)
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] Shape of 2D image: (320, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Shape of data cube: (4, 320, 320)
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] Shape of data cube: (4, 320, 320)
# [stcal.ramp_fitting.ols_fit:DEBUG] Buffer size (bytes): 307200000
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] Buffer size (bytes): 307200000
# [stcal.ramp_fitting.ols_fit:DEBUG] Number of rows per buffer: 320
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] Number of rows per buffer: 320
# [stcal.ramp_fitting.ols_fit:INFO] Number of groups per integration: 4
# 2022-04-22 15:31:04,574 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 4
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Number of groups per integration: 4
# [stcal.ramp_fitting.ols_fit:INFO] Number of integrations: 2
# 2022-04-22 15:31:04,575 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 2
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Number of integrations: 2
# [stcal.ramp_fitting.ols_fit:DEBUG] The execution time in seconds: 0.356622
# [stpipe.Detector1Pipeline.ramp_fit:DEBUG] The execution time in seconds: 0.356622
# 2022-04-22 15:31:04,670 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# [stpipe.Detector1Pipeline.ramp_fit:INFO] Step ramp_fit done
# 2022-04-22 15:31:04,776 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(320, 320) from pynrc_jw01386001001_0310A_00001_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.gain_scale:INFO] Step gain_scale running with args (<ImageModel(320, 320) from pynrc_jw01386001001_0310A_00001_nrca5_uncal.fits>,).
# 2022-04-22 15:31:04,778 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# [stpipe.Detector1Pipeline.gain_scale:INFO] Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# 2022-04-22 15:31:04,854 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# [stpipe.Detector1Pipeline.gain_scale:INFO] GAINFACT not found in gain reference file
# 2022-04-22 15:31:04,855 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# [stpipe.Detector1Pipeline.gain_scale:INFO] Step will be skipped
# 2022-04-22 15:31:04,862 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# [stpipe.Detector1Pipeline.gain_scale:INFO] Step gain_scale done
# 2022-04-22 15:31:04,967 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(2, 320, 320) from pynrc_jw01386001001_0310A_00001_nrca5_uncal.fits>,).
# [stpipe.Detector1Pipeline.gain_scale:INFO] Step gain_scale running with args (<CubeModel(2, 320, 320) from pynrc_jw01386001001_0310A_00001_nrca5_uncal.fits>,).
# 2022-04-22 15:31:04,969 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# [stpipe.Detector1Pipeline.gain_scale:INFO] Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/DATA/HIFI_SIMS/NIRCam/20220407/small_uncal'}
# 2022-04-22 15:31:05,052 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# [stpipe.Detector1Pipeline.gain_scale:INFO] GAINFACT not found in gain reference file
# 2022-04-22 15:31:05,053 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# [stpipe.Detector1Pipeline.gain_scale:INFO] Step will be skipped
# 2022-04-22 15:31:05,060 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# [stpipe.Detector1Pipeline.gain_scale:INFO] Step gain_scale done
# 2022-04-22 15:31:05,165 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00001_nrca5_rateints.fits
# [stpipe.Detector1Pipeline:INFO] Saved model in /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00001_nrca5_rateints.fits
# [jwst.pipeline.calwebb_detector1:INFO] ... ending calwebb_detector1
# 2022-04-22 15:31:05,168 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# [stpipe.Detector1Pipeline:INFO] ... ending calwebb_detector1
# 2022-04-22 15:31:05,260 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00001_nrca5_rate.fits
# [stpipe.Detector1Pipeline:INFO] Saved model in /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00001_nrca5_rate.fits
# 2022-04-22 15:31:05,263 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# [stpipe.Detector1Pipeline:INFO] Step Detector1Pipeline done

# %%
# Perform image processing
pipeline.imgprocess()
# Out:
# 2022-04-22 15:31:05,276 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# Found 11 files under: /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/
# [stpipe.Image2Pipeline:INFO] Image2Pipeline instance created.
# 2022-04-22 15:31:05,278 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# [stpipe.Image2Pipeline.bkg_subtract:INFO] BackgroundStep instance created.
# 2022-04-22 15:31:05,280 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# [stpipe.Image2Pipeline.assign_wcs:INFO] AssignWcsStep instance created.
# 2022-04-22 15:31:05,282 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# [stpipe.Image2Pipeline.flat_field:INFO] FlatFieldStep instance created.
# 2022-04-22 15:31:05,284 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# [stpipe.Image2Pipeline.photom:INFO] PhotomStep instance created.
# 2022-04-22 15:31:05,287 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# [stpipe.Image2Pipeline.resample:INFO] ResampleStep instance created.
# 2022-04-22 15:31:05,396 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline running with args ('/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits',).
# [stpipe.Image2Pipeline:INFO] Step Image2Pipeline running with args ('/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits',).
# 2022-04-22 15:31:05,402 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/IMGPROCESS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None}}}
# [stpipe.Image2Pipeline:INFO] Step Image2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/IMGPROCESS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None}}}
# 2022-04-22 15:31:05,486 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# [stpipe.Image2Pipeline:INFO] Prefetching reference files for dataset: 'pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-04-22 15:31:05,491 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# [stpipe.Image2Pipeline:INFO] Prefetch for AREA reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# 2022-04-22 15:31:05,492 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for CAMERA reference file is 'N/A'.
# 2022-04-22 15:31:05,493 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-04-22 15:31:05,494 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for DFLAT reference file is 'N/A'.
# 2022-04-22 15:31:05,495 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for DISPERSER reference file is 'N/A'.
# 2022-04-22 15:31:05,496 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf'.
# [stpipe.Image2Pipeline:INFO] Prefetch for DISTORTION reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf'.
# 2022-04-22 15:31:05,499 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# [stpipe.Image2Pipeline:INFO] Prefetch for DRIZPARS reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# 2022-04-22 15:31:05,500 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FFLAT reference file is 'N/A'.
# 2022-04-22 15:31:05,501 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FILTEROFFSET reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf'.
# 2022-04-22 15:31:05,503 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_flat_0465.fits'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FLAT reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_flat_0465.fits'.
# 2022-04-22 15:31:05,505 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FORE reference file is 'N/A'.
# 2022-04-22 15:31:05,506 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FPA reference file is 'N/A'.
# 2022-04-22 15:31:05,508 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for IFUFORE reference file is 'N/A'.
# 2022-04-22 15:31:05,509 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for IFUPOST reference file is 'N/A'.
# 2022-04-22 15:31:05,510 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-04-22 15:31:05,510 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for MSA reference file is 'N/A'.
# 2022-04-22 15:31:05,511 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for OTE reference file is 'N/A'.
# 2022-04-22 15:31:05,512 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_photom_0092.fits'.
# [stpipe.Image2Pipeline:INFO] Prefetch for PHOTOM reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_photom_0092.fits'.
# 2022-04-22 15:31:05,514 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for REGIONS reference file is 'N/A'.
# 2022-04-22 15:31:05,515 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for SFLAT reference file is 'N/A'.
# 2022-04-22 15:31:05,517 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for SPECWCS reference file is 'N/A'.
# 2022-04-22 15:31:05,518 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-04-22 15:31:05,519 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-04-22 15:31:05,520 - stpipe.Image2Pipeline - INFO - Starting calwebb_image2 ...
# [stpipe.Image2Pipeline:INFO] Starting calwebb_image2 ...
# 2022-04-22 15:31:05,521 - stpipe.Image2Pipeline - INFO - Processing product /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386002001_0310A_00001_nrca5
# [stpipe.Image2Pipeline:INFO] Processing product /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386002001_0310A_00001_nrca5
# 2022-04-22 15:31:05,523 - stpipe.Image2Pipeline - INFO - Working on input /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits ...
# [stpipe.Image2Pipeline:INFO] Working on input /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits ...
# 2022-04-22 15:31:05,713 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(2, 320, 320) from pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits>,).
# [stpipe.Image2Pipeline.assign_wcs:INFO] Step assign_wcs running with args (<CubeModel(2, 320, 320) from pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits>,).
# 2022-04-22 15:31:05,715 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [stpipe.Image2Pipeline.assign_wcs:INFO] Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [jwst.assign_wcs.assign_wcs_step:DEBUG] reference files used in assign_wcs: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [stpipe.Image2Pipeline.assign_wcs:DEBUG] reference files used in assign_wcs: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [jwst.assign_wcs.nircam:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [stpipe.Image2Pipeline.assign_wcs:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [jwst.assign_wcs.util:INFO] Update S_REGION to POLYGON ICRS  201.144432439 -51.506047982 201.152888325 -51.507912220 201.155811781 -51.502711823 201.147355189 -51.500838364
# 2022-04-22 15:31:06,151 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  201.144432439 -51.506047982 201.152888325 -51.507912220 201.155811781 -51.502711823 201.147355189 -51.500838364
# [stpipe.Image2Pipeline.assign_wcs:INFO] Update S_REGION to POLYGON ICRS  201.144432439 -51.506047982 201.152888325 -51.507912220 201.155811781 -51.502711823 201.147355189 -51.500838364
# [jwst.assign_wcs.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  201.144432439 -51.506047982 201.152888325 -51.507912220 201.155811781 -51.502711823 201.147355189 -51.500838364
# 2022-04-22 15:31:06,153 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  201.144432439 -51.506047982 201.152888325 -51.507912220 201.155811781 -51.502711823 201.147355189 -51.500838364
# [stpipe.Image2Pipeline.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  201.144432439 -51.506047982 201.152888325 -51.507912220 201.155811781 -51.502711823 201.147355189 -51.500838364
# [jwst.assign_wcs.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-04-22 15:31:06,155 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# [stpipe.Image2Pipeline.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-04-22 15:31:06,226 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# [stpipe.Image2Pipeline.assign_wcs:INFO] Step assign_wcs done
# 2022-04-22 15:31:06,331 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(2, 320, 320) from pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits>,).
# [stpipe.Image2Pipeline.flat_field:INFO] Step flat_field running with args (<CubeModel(2, 320, 320) from pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits>,).
# 2022-04-22 15:31:06,333 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Image2Pipeline.flat_field:INFO] Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Image2Pipeline.flat_field:DEBUG] Input is CubeModel of exposure type NRC_CORON
# [stpipe.Image2Pipeline.flat_field:DEBUG] Using FLAT reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_flat_0465.fits
# [stpipe.Image2Pipeline.flat_field:DEBUG] No reference found for type FFLAT
# [stpipe.Image2Pipeline.flat_field:DEBUG] No reference found for type SFLAT
# [stpipe.Image2Pipeline.flat_field:DEBUG] No reference found for type DFLAT
# [jwst.flatfield.flat_field:DEBUG] Flat field correction for non-NIRSpec modes.
# [stpipe.Image2Pipeline.flat_field:DEBUG] Flat field correction for non-NIRSpec modes.
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Image2Pipeline.flat_field:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Image2Pipeline.flat_field:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.flatfield.flat_field:INFO] Extracting matching subarray from flat
# 2022-04-22 15:31:06,630 - stpipe.Image2Pipeline.flat_field - INFO - Extracting matching subarray from flat
# [stpipe.Image2Pipeline.flat_field:INFO] Extracting matching subarray from flat
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Image2Pipeline.flat_field:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-04-22 15:31:06,672 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# [stpipe.Image2Pipeline.flat_field:INFO] Step flat_field done
# 2022-04-22 15:31:06,779 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<CubeModel(2, 320, 320) from pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits>,).
# [stpipe.Image2Pipeline.photom:INFO] Step photom running with args (<CubeModel(2, 320, 320) from pynrc_jw01386002001_0310A_00001_nrca5_rateints.fits>,).
# 2022-04-22 15:31:06,782 - stpipe.Image2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'inverse': False, 'source_type': None}
# [stpipe.Image2Pipeline.photom:INFO] Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'inverse': False, 'source_type': None}
# [stpipe.Image2Pipeline.photom:DEBUG] Input is CubeModel
# 2022-04-22 15:31:06,824 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_photom_0092.fits
# [stpipe.Image2Pipeline.photom:INFO] Using photom reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_photom_0092.fits
# 2022-04-22 15:31:06,826 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_area_0014.fits
# [stpipe.Image2Pipeline.photom:INFO] Using area reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_area_0014.fits
# [jwst.photom.photom:INFO] Using instrument: NIRCAM
# 2022-04-22 15:31:06,926 - stpipe.Image2Pipeline.photom - INFO - Using instrument: NIRCAM
# [stpipe.Image2Pipeline.photom:INFO] Using instrument: NIRCAM
# [jwst.photom.photom:INFO]  detector: NRCALONG
# 2022-04-22 15:31:06,929 - stpipe.Image2Pipeline.photom - INFO -  detector: NRCALONG
# [stpipe.Image2Pipeline.photom:INFO]  detector: NRCALONG
# [jwst.photom.photom:INFO]  exp_type: NRC_CORON
# 2022-04-22 15:31:06,931 - stpipe.Image2Pipeline.photom - INFO -  exp_type: NRC_CORON
# [stpipe.Image2Pipeline.photom:INFO]  exp_type: NRC_CORON
# [jwst.photom.photom:INFO]  filter: F444W
# 2022-04-22 15:31:06,932 - stpipe.Image2Pipeline.photom - INFO -  filter: F444W
# [stpipe.Image2Pipeline.photom:INFO]  filter: F444W
# [jwst.photom.photom:INFO]  pupil: MASKRND
# 2022-04-22 15:31:06,933 - stpipe.Image2Pipeline.photom - INFO -  pupil: MASKRND
# [stpipe.Image2Pipeline.photom:INFO]  pupil: MASKRND
# [jwst.photom.photom:INFO] Pixel area map copied to output.
# 2022-04-22 15:31:07,033 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# [stpipe.Image2Pipeline.photom:INFO] Pixel area map copied to output.
# [jwst.photom.photom:DEBUG] PIXAR_SR = 9.30710330396321e-14, PIXAR_A2 = 0.003959722950309959
# [stpipe.Image2Pipeline.photom:DEBUG] PIXAR_SR = 9.30710330396321e-14, PIXAR_A2 = 0.003959722950309959
# [jwst.photom.photom:INFO] PHOTMJSR value: 2.58444
# 2022-04-22 15:31:07,038 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 2.58444
# [stpipe.Image2Pipeline.photom:INFO] PHOTMJSR value: 2.58444
# 2022-04-22 15:31:07,060 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# [stpipe.Image2Pipeline.photom:INFO] Step photom done
# 2022-04-22 15:31:07,061 - stpipe.Image2Pipeline - INFO - Finished processing product /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386002001_0310A_00001_nrca5
# [stpipe.Image2Pipeline:INFO] Finished processing product /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386002001_0310A_00001_nrca5
# 2022-04-22 15:31:07,065 - stpipe.Image2Pipeline - INFO - ... ending calwebb_image2
# [stpipe.Image2Pipeline:INFO] ... ending calwebb_image2
# 2022-04-22 15:31:07,326 - stpipe.Image2Pipeline - INFO - Saved model in /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/IMGPROCESS/pynrc_jw01386002001_0310A_00001_nrca5_calints.fits
# [stpipe.Image2Pipeline:INFO] Saved model in /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/IMGPROCESS/pynrc_jw01386002001_0310A_00001_nrca5_calints.fits
# 2022-04-22 15:31:07,327 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done
# [stpipe.Image2Pipeline:INFO] Step Image2Pipeline done
# 2022-04-22 15:31:07,334 - stpipe.Image2Pipeline - INFO - Image2Pipeline instance created.
# [stpipe.Image2Pipeline:INFO] Image2Pipeline instance created.
# 2022-04-22 15:31:07,336 - stpipe.Image2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# [stpipe.Image2Pipeline.bkg_subtract:INFO] BackgroundStep instance created.
# 2022-04-22 15:31:07,339 - stpipe.Image2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# [stpipe.Image2Pipeline.assign_wcs:INFO] AssignWcsStep instance created.
# 2022-04-22 15:31:07,341 - stpipe.Image2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# [stpipe.Image2Pipeline.flat_field:INFO] FlatFieldStep instance created.
# 2022-04-22 15:31:07,343 - stpipe.Image2Pipeline.photom - INFO - PhotomStep instance created.
# [stpipe.Image2Pipeline.photom:INFO] PhotomStep instance created.
# 2022-04-22 15:31:07,346 - stpipe.Image2Pipeline.resample - INFO - ResampleStep instance created.
# [stpipe.Image2Pipeline.resample:INFO] ResampleStep instance created.
# 2022-04-22 15:31:07,470 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline running with args ('/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits',).
# [stpipe.Image2Pipeline:INFO] Step Image2Pipeline running with args ('/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits',).
# 2022-04-22 15:31:07,477 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/IMGPROCESS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None}}}
# [stpipe.Image2Pipeline:INFO] Step Image2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/IMGPROCESS/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'resample': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'single': False, 'blendheaders': True, 'allowed_memory': None}}}
# 2022-04-22 15:31:07,556 - stpipe.Image2Pipeline - INFO - Prefetching reference files for dataset: 'pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# [stpipe.Image2Pipeline:INFO] Prefetching reference files for dataset: 'pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits' reftypes = ['area', 'camera', 'collimator', 'dflat', 'disperser', 'distortion', 'drizpars', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'photom', 'regions', 'sflat', 'specwcs', 'wavelengthrange', 'wfssbkg']
# 2022-04-22 15:31:07,563 - stpipe.Image2Pipeline - INFO - Prefetch for AREA reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# [stpipe.Image2Pipeline:INFO] Prefetch for AREA reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_area_0014.fits'.
# 2022-04-22 15:31:07,565 - stpipe.Image2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for CAMERA reference file is 'N/A'.
# 2022-04-22 15:31:07,566 - stpipe.Image2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for COLLIMATOR reference file is 'N/A'.
# 2022-04-22 15:31:07,567 - stpipe.Image2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for DFLAT reference file is 'N/A'.
# 2022-04-22 15:31:07,568 - stpipe.Image2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for DISPERSER reference file is 'N/A'.
# 2022-04-22 15:31:07,570 - stpipe.Image2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf'.
# [stpipe.Image2Pipeline:INFO] Prefetch for DISTORTION reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf'.
# 2022-04-22 15:31:07,571 - stpipe.Image2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# [stpipe.Image2Pipeline:INFO] Prefetch for DRIZPARS reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_drizpars_0001.fits'.
# 2022-04-22 15:31:07,572 - stpipe.Image2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FFLAT reference file is 'N/A'.
# 2022-04-22 15:31:07,573 - stpipe.Image2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FILTEROFFSET reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf'.
# 2022-04-22 15:31:07,573 - stpipe.Image2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_flat_0465.fits'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FLAT reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_flat_0465.fits'.
# 2022-04-22 15:31:07,574 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FORE reference file is 'N/A'.
# 2022-04-22 15:31:07,575 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FPA reference file is 'N/A'.
# 2022-04-22 15:31:07,576 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for IFUFORE reference file is 'N/A'.
# 2022-04-22 15:31:07,577 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for IFUPOST reference file is 'N/A'.
# 2022-04-22 15:31:07,578 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-04-22 15:31:07,579 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for MSA reference file is 'N/A'.
# 2022-04-22 15:31:07,580 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for OTE reference file is 'N/A'.
# 2022-04-22 15:31:07,581 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_photom_0092.fits'.
# [stpipe.Image2Pipeline:INFO] Prefetch for PHOTOM reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_photom_0092.fits'.
# 2022-04-22 15:31:07,582 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for REGIONS reference file is 'N/A'.
# 2022-04-22 15:31:07,583 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for SFLAT reference file is 'N/A'.
# 2022-04-22 15:31:07,585 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for SPECWCS reference file is 'N/A'.
# 2022-04-22 15:31:07,586 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-04-22 15:31:07,587 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-04-22 15:31:07,589 - stpipe.Image2Pipeline - INFO - Starting calwebb_image2 ...
# [stpipe.Image2Pipeline:INFO] Starting calwebb_image2 ...
# 2022-04-22 15:31:07,590 - stpipe.Image2Pipeline - INFO - Processing product /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386003001_0310A_00001_nrca5
# [stpipe.Image2Pipeline:INFO] Processing product /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386003001_0310A_00001_nrca5
# 2022-04-22 15:31:07,590 - stpipe.Image2Pipeline - INFO - Working on input /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits ...
# [stpipe.Image2Pipeline:INFO] Working on input /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits ...
# 2022-04-22 15:31:07,786 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(2, 320, 320) from pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits>,).
# [stpipe.Image2Pipeline.assign_wcs:INFO] Step assign_wcs running with args (<CubeModel(2, 320, 320) from pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits>,).
# 2022-04-22 15:31:07,788 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [stpipe.Image2Pipeline.assign_wcs:INFO] Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [jwst.assign_wcs.assign_wcs_step:DEBUG] reference files used in assign_wcs: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [stpipe.Image2Pipeline.assign_wcs:DEBUG] reference files used in assign_wcs: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [jwst.assign_wcs.nircam:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [stpipe.Image2Pipeline.assign_wcs:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [jwst.assign_wcs.util:INFO] Update S_REGION to POLYGON ICRS  201.145022473 -51.506722056 201.153891965 -51.507558408 201.155184426 -51.502107888 201.146311584 -51.501262555
# 2022-04-22 15:31:08,225 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  201.145022473 -51.506722056 201.153891965 -51.507558408 201.155184426 -51.502107888 201.146311584 -51.501262555
# [stpipe.Image2Pipeline.assign_wcs:INFO] Update S_REGION to POLYGON ICRS  201.145022473 -51.506722056 201.153891965 -51.507558408 201.155184426 -51.502107888 201.146311584 -51.501262555
# [jwst.assign_wcs.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  201.145022473 -51.506722056 201.153891965 -51.507558408 201.155184426 -51.502107888 201.146311584 -51.501262555
# 2022-04-22 15:31:08,227 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  201.145022473 -51.506722056 201.153891965 -51.507558408 201.155184426 -51.502107888 201.146311584 -51.501262555
# [stpipe.Image2Pipeline.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  201.145022473 -51.506722056 201.153891965 -51.507558408 201.155184426 -51.502107888 201.146311584 -51.501262555
# [jwst.assign_wcs.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-04-22 15:31:08,229 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# [stpipe.Image2Pipeline.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-04-22 15:31:08,303 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# [stpipe.Image2Pipeline.assign_wcs:INFO] Step assign_wcs done
# 2022-04-22 15:31:08,419 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(2, 320, 320) from pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits>,).
# [stpipe.Image2Pipeline.flat_field:INFO] Step flat_field running with args (<CubeModel(2, 320, 320) from pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits>,).
# 2022-04-22 15:31:08,421 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Image2Pipeline.flat_field:INFO] Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Image2Pipeline.flat_field:DEBUG] Input is CubeModel of exposure type NRC_CORON
# [stpipe.Image2Pipeline.flat_field:DEBUG] Using FLAT reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_flat_0465.fits
# [stpipe.Image2Pipeline.flat_field:DEBUG] No reference found for type FFLAT
# [stpipe.Image2Pipeline.flat_field:DEBUG] No reference found for type SFLAT
# [stpipe.Image2Pipeline.flat_field:DEBUG] No reference found for type DFLAT
# [jwst.flatfield.flat_field:DEBUG] Flat field correction for non-NIRSpec modes.
# [stpipe.Image2Pipeline.flat_field:DEBUG] Flat field correction for non-NIRSpec modes.
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Image2Pipeline.flat_field:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Image2Pipeline.flat_field:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.flatfield.flat_field:INFO] Extracting matching subarray from flat
# 2022-04-22 15:31:08,725 - stpipe.Image2Pipeline.flat_field - INFO - Extracting matching subarray from flat
# [stpipe.Image2Pipeline.flat_field:INFO] Extracting matching subarray from flat
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Image2Pipeline.flat_field:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-04-22 15:31:08,763 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# [stpipe.Image2Pipeline.flat_field:INFO] Step flat_field done
# 2022-04-22 15:31:08,872 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<CubeModel(2, 320, 320) from pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits>,).
# [stpipe.Image2Pipeline.photom:INFO] Step photom running with args (<CubeModel(2, 320, 320) from pynrc_jw01386003001_0310A_00001_nrca5_rateints.fits>,).
# 2022-04-22 15:31:08,875 - stpipe.Image2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'inverse': False, 'source_type': None}
# [stpipe.Image2Pipeline.photom:INFO] Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'inverse': False, 'source_type': None}
# [stpipe.Image2Pipeline.photom:DEBUG] Input is CubeModel
# ...
# 2022-04-22 15:31:25,874 - stpipe.Image2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FORE reference file is 'N/A'.
# 2022-04-22 15:31:25,875 - stpipe.Image2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for FPA reference file is 'N/A'.
# 2022-04-22 15:31:25,876 - stpipe.Image2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for IFUFORE reference file is 'N/A'.
# 2022-04-22 15:31:25,877 - stpipe.Image2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for IFUPOST reference file is 'N/A'.
# 2022-04-22 15:31:25,878 - stpipe.Image2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for IFUSLICER reference file is 'N/A'.
# 2022-04-22 15:31:25,879 - stpipe.Image2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for MSA reference file is 'N/A'.
# 2022-04-22 15:31:25,880 - stpipe.Image2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for OTE reference file is 'N/A'.
# 2022-04-22 15:31:25,881 - stpipe.Image2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_photom_0092.fits'.
# [stpipe.Image2Pipeline:INFO] Prefetch for PHOTOM reference file is '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_photom_0092.fits'.
# 2022-04-22 15:31:25,882 - stpipe.Image2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for REGIONS reference file is 'N/A'.
# 2022-04-22 15:31:25,882 - stpipe.Image2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for SFLAT reference file is 'N/A'.
# 2022-04-22 15:31:25,883 - stpipe.Image2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for SPECWCS reference file is 'N/A'.
# 2022-04-22 15:31:25,884 - stpipe.Image2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2022-04-22 15:31:25,885 - stpipe.Image2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# [stpipe.Image2Pipeline:INFO] Prefetch for WFSSBKG reference file is 'N/A'.
# 2022-04-22 15:31:25,886 - stpipe.Image2Pipeline - INFO - Starting calwebb_image2 ...
# [stpipe.Image2Pipeline:INFO] Starting calwebb_image2 ...
# 2022-04-22 15:31:25,887 - stpipe.Image2Pipeline - INFO - Processing product /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00005_nrca5
# [stpipe.Image2Pipeline:INFO] Processing product /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00005_nrca5
# 2022-04-22 15:31:25,888 - stpipe.Image2Pipeline - INFO - Working on input /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00005_nrca5_rateints.fits ...
# [stpipe.Image2Pipeline:INFO] Working on input /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00005_nrca5_rateints.fits ...
# 2022-04-22 15:31:26,091 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(2, 320, 320) from pynrc_jw01386001001_0310A_00005_nrca5_rateints.fits>,).
# [stpipe.Image2Pipeline.assign_wcs:INFO] Step assign_wcs running with args (<CubeModel(2, 320, 320) from pynrc_jw01386001001_0310A_00005_nrca5_rateints.fits>,).
# 2022-04-22 15:31:26,094 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [stpipe.Image2Pipeline.assign_wcs:INFO] Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# [jwst.assign_wcs.assign_wcs_step:DEBUG] reference files used in assign_wcs: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [stpipe.Image2Pipeline.assign_wcs:DEBUG] reference files used in assign_wcs: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': 'N/A', 'regions': 'N/A', 'wavelengthrange': 'N/A', 'camera': 'N/A', 'collimator': 'N/A', 'disperser': 'N/A', 'fore': 'N/A', 'fpa': 'N/A', 'msa': 'N/A', 'ote': 'N/A', 'ifupost': 'N/A', 'ifufore': 'N/A', 'ifuslicer': 'N/A'}
# [jwst.assign_wcs.nircam:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [stpipe.Image2Pipeline.assign_wcs:DEBUG] reference files used in NIRCAM WCS pipeline: {'distortion': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_distortion_0130.asdf', 'filteroffset': '/Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_filteroffset_0002.asdf', 'specwcs': None, 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# [jwst.assign_wcs.util:INFO] Update S_REGION to POLYGON ICRS  209.562817408 -42.102706838 209.570081800 -42.104165153 209.571994022 -42.098841395 209.564727931 -42.097373869
# 2022-04-22 15:31:26,516 - stpipe.Image2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  209.562817408 -42.102706838 209.570081800 -42.104165153 209.571994022 -42.098841395 209.564727931 -42.097373869
# [stpipe.Image2Pipeline.assign_wcs:INFO] Update S_REGION to POLYGON ICRS  209.562817408 -42.102706838 209.570081800 -42.104165153 209.571994022 -42.098841395 209.564727931 -42.097373869
# [jwst.assign_wcs.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  209.562817408 -42.102706838 209.570081800 -42.104165153 209.571994022 -42.098841395 209.564727931 -42.097373869
# 2022-04-22 15:31:26,518 - stpipe.Image2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  209.562817408 -42.102706838 209.570081800 -42.104165153 209.571994022 -42.098841395 209.564727931 -42.097373869
# [stpipe.Image2Pipeline.assign_wcs:INFO] assign_wcs updated S_REGION to POLYGON ICRS  209.562817408 -42.102706838 209.570081800 -42.104165153 209.571994022 -42.098841395 209.564727931 -42.097373869
# [jwst.assign_wcs.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-04-22 15:31:26,520 - stpipe.Image2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# [stpipe.Image2Pipeline.assign_wcs:INFO] COMPLETED assign_wcs
# 2022-04-22 15:31:26,584 - stpipe.Image2Pipeline.assign_wcs - INFO - Step assign_wcs done
# [stpipe.Image2Pipeline.assign_wcs:INFO] Step assign_wcs done
# 2022-04-22 15:31:26,700 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field running with args (<CubeModel(2, 320, 320) from pynrc_jw01386001001_0310A_00005_nrca5_rateints.fits>,).
# [stpipe.Image2Pipeline.flat_field:INFO] Step flat_field running with args (<CubeModel(2, 320, 320) from pynrc_jw01386001001_0310A_00005_nrca5_rateints.fits>,).
# 2022-04-22 15:31:26,702 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Image2Pipeline.flat_field:INFO] Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# [stpipe.Image2Pipeline.flat_field:DEBUG] Input is CubeModel of exposure type NRC_CORON
# [stpipe.Image2Pipeline.flat_field:DEBUG] Using FLAT reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_flat_0465.fits
# [stpipe.Image2Pipeline.flat_field:DEBUG] No reference found for type FFLAT
# [stpipe.Image2Pipeline.flat_field:DEBUG] No reference found for type SFLAT
# [stpipe.Image2Pipeline.flat_field:DEBUG] No reference found for type DFLAT
# [jwst.flatfield.flat_field:DEBUG] Flat field correction for non-NIRSpec modes.
# [stpipe.Image2Pipeline.flat_field:DEBUG] Flat field correction for non-NIRSpec modes.
# [jwst.lib.reffile_utils:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [stpipe.Image2Pipeline.flat_field:DEBUG] ref substrt1=1, subsize1=2048, substrt2=1, subsize2=2048
# [jwst.lib.reffile_utils:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [stpipe.Image2Pipeline.flat_field:DEBUG] sci substrt1=492, subsize1=320, substrt2=1502, subsize2=320
# [jwst.flatfield.flat_field:INFO] Extracting matching subarray from flat
# 2022-04-22 15:31:26,960 - stpipe.Image2Pipeline.flat_field - INFO - Extracting matching subarray from flat
# [stpipe.Image2Pipeline.flat_field:INFO] Extracting matching subarray from flat
# [jwst.lib.reffile_utils:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# [stpipe.Image2Pipeline.flat_field:DEBUG] slice xstart=491, xstop=811, ystart=1501, ystop=1821
# 2022-04-22 15:31:26,997 - stpipe.Image2Pipeline.flat_field - INFO - Step flat_field done
# [stpipe.Image2Pipeline.flat_field:INFO] Step flat_field done
# 2022-04-22 15:31:27,116 - stpipe.Image2Pipeline.photom - INFO - Step photom running with args (<CubeModel(2, 320, 320) from pynrc_jw01386001001_0310A_00005_nrca5_rateints.fits>,).
# [stpipe.Image2Pipeline.photom:INFO] Step photom running with args (<CubeModel(2, 320, 320) from pynrc_jw01386001001_0310A_00005_nrca5_rateints.fits>,).
# 2022-04-22 15:31:27,118 - stpipe.Image2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'inverse': False, 'source_type': None}
# [stpipe.Image2Pipeline.photom:INFO] Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT', 'inverse': False, 'source_type': None}
# [stpipe.Image2Pipeline.photom:DEBUG] Input is CubeModel
# 2022-04-22 15:31:27,161 - stpipe.Image2Pipeline.photom - INFO - Using photom reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_photom_0092.fits
# [stpipe.Image2Pipeline.photom:INFO] Using photom reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_photom_0092.fits
# 2022-04-22 15:31:27,162 - stpipe.Image2Pipeline.photom - INFO - Using area reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_area_0014.fits
# [stpipe.Image2Pipeline.photom:INFO] Using area reference file: /Users/acarter/crds_cache/references/jwst/nircam/jwst_nircam_area_0014.fits
# [jwst.photom.photom:INFO] Using instrument: NIRCAM
# 2022-04-22 15:31:27,262 - stpipe.Image2Pipeline.photom - INFO - Using instrument: NIRCAM
# [stpipe.Image2Pipeline.photom:INFO] Using instrument: NIRCAM
# [jwst.photom.photom:INFO]  detector: NRCALONG
# 2022-04-22 15:31:27,264 - stpipe.Image2Pipeline.photom - INFO -  detector: NRCALONG
# [stpipe.Image2Pipeline.photom:INFO]  detector: NRCALONG
# [jwst.photom.photom:INFO]  exp_type: NRC_CORON
# 2022-04-22 15:31:27,266 - stpipe.Image2Pipeline.photom - INFO -  exp_type: NRC_CORON
# [stpipe.Image2Pipeline.photom:INFO]  exp_type: NRC_CORON
# [jwst.photom.photom:INFO]  filter: F444W
# 2022-04-22 15:31:27,268 - stpipe.Image2Pipeline.photom - INFO -  filter: F444W
# [stpipe.Image2Pipeline.photom:INFO]  filter: F444W
# [jwst.photom.photom:INFO]  pupil: MASKRND
# 2022-04-22 15:31:27,270 - stpipe.Image2Pipeline.photom - INFO -  pupil: MASKRND
# [stpipe.Image2Pipeline.photom:INFO]  pupil: MASKRND
# [jwst.photom.photom:INFO] Pixel area map copied to output.
# 2022-04-22 15:31:27,358 - stpipe.Image2Pipeline.photom - INFO - Pixel area map copied to output.
# [stpipe.Image2Pipeline.photom:INFO] Pixel area map copied to output.
# [jwst.photom.photom:DEBUG] PIXAR_SR = 9.30710330396321e-14, PIXAR_A2 = 0.003959722950309959
# [stpipe.Image2Pipeline.photom:DEBUG] PIXAR_SR = 9.30710330396321e-14, PIXAR_A2 = 0.003959722950309959
# [jwst.photom.photom:INFO] PHOTMJSR value: 2.58444
# 2022-04-22 15:31:27,364 - stpipe.Image2Pipeline.photom - INFO - PHOTMJSR value: 2.58444
# [stpipe.Image2Pipeline.photom:INFO] PHOTMJSR value: 2.58444
# 2022-04-22 15:31:27,385 - stpipe.Image2Pipeline.photom - INFO - Step photom done
# [stpipe.Image2Pipeline.photom:INFO] Step photom done
# 2022-04-22 15:31:27,386 - stpipe.Image2Pipeline - INFO - Finished processing product /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00005_nrca5
# [stpipe.Image2Pipeline:INFO] Finished processing product /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/RAMPFIT/pynrc_jw01386001001_0310A_00005_nrca5
# 2022-04-22 15:31:27,389 - stpipe.Image2Pipeline - INFO - ... ending calwebb_image2
# [stpipe.Image2Pipeline:INFO] ... ending calwebb_image2
# 2022-04-22 15:31:27,643 - stpipe.Image2Pipeline - INFO - Saved model in /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/IMGPROCESS/pynrc_jw01386001001_0310A_00005_nrca5_calints.fits
# [stpipe.Image2Pipeline:INFO] Saved model in /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/IMGPROCESS/pynrc_jw01386001001_0310A_00005_nrca5_calints.fits
# 2022-04-22 15:31:27,644 - stpipe.Image2Pipeline - INFO - Step Image2Pipeline done
# [stpipe.Image2Pipeline:INFO] Step Image2Pipeline done

# %%
# Perform PSF Subtraction
pipeline.subtraction()
# Out:
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedColumn.
#   a.partition(kth, axis=axis, kind=kind, order=order)
#
# 2022-04-22 15:31:27,786 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedColumn.
#   a.partition(kth, axis=axis, kind=kind, order=order)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/numpy/core/fromnumeric.py:758: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedColumn.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# --> Running pyKLIP...
# Found 11 files under: /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/IMGPROCESS/
# --> Identified 1 observation sequences
# --> Sequence 1: NIRCAM_NRCALONG_F444W_MASKRND_MASKA335R_SUB320A335R
# TYP  TARGPROP  TARG_RA   TARG_DEC READPATT NINTS NGROUPS NFRAMES EFFINTTM PIXSCALE  PA_V3
# --- --------- --------- --------- -------- ----- ------- ------- -------- -------- --------
# SCI HIP-65426  201.1504 -51.50446    DEEP8     2      15       8 307.8835     63.0 98.43421
# SCI HIP-65426  201.1504 -51.50446    DEEP8     2      15       8 307.8835     63.0 109.3231
# CAL HIP-68245 209.56764 -42.10084  MEDIUM8     2       4       8 40.62352     63.0    105.0
# CAL HIP-68245 209.56764 -42.10084  MEDIUM8     2       4       8 40.62352     63.0    105.0
# CAL HIP-68245 209.56764 -42.10084  MEDIUM8     2       4       8 40.62352     63.0    105.0
# CAL HIP-68245 209.56764 -42.10084  MEDIUM8     2       4       8 40.62352     63.0    105.0
# CAL HIP-68245 209.56764 -42.10084  MEDIUM8     2       4       8 40.62352     63.0    105.0
# CAL HIP-68245 209.56764 -42.10084  MEDIUM8     2       4       8 40.62352     63.0    105.0
# CAL HIP-68245 209.56764 -42.10084  MEDIUM8     2       4       8 40.62352     63.0    105.0
# CAL HIP-68245 209.56764 -42.10084  MEDIUM8     2       4       8 40.62352     63.0    105.0
# CAL HIP-68245 209.56764 -42.10084  MEDIUM8     2       4       8 40.62352     63.0    105.0
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/webbpsf_ext/spectra.py:626: UserWarning: Warning: converting a masked element to nan.
#   uflux_e = np.array(uflux_e)
#
# 2022-04-22 15:31:27,850 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/webbpsf_ext/spectra.py:626: UserWarning: Warning: converting a masked element to nan.
#   uflux_e = np.array(uflux_e)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/webbpsf_ext/spectra.py:626: UserWarning: Warning: converting a masked element to nan.
#   uflux_e = np.array(uflux_e)
# --> Mode = RDI, annuli = 1, subsections = 1, scenario 1 of 1
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# Begin align and scale images for each wavelength
# Wavelength 4.439 with index 0 has finished align and scale. Queuing for KLIP
# Total number of tasks for KLIP processing is 1
# Closing threadpool
# Derotating Images...
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:31:37,498 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# Writing Images to directory /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/2022_04_22_RDI_annu1_subs1_run4/SUBTRACTED
# wavelength collapsing reduced data of shape (b, N, wv, y, x):(4, 4, 1, 320, 320)

# %%
# Compute raw contrast
pipeline.raw_contrast()
# Out:
# --> Computing raw contrast curve...
# --> Mode = RDI, annuli = annu1, subsections = subs1, scenario 1 of 1
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# 2022-04-22 15:31:38,076 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# 2022-04-22 15:31:38,078 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/pyklip/klip.py:539: RuntimeWarning: Mean of empty slice
#   noise_mean = np.nanmean(filtered[annulus])
#
# 2022-04-22 15:31:38,197 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/pyklip/klip.py:539: RuntimeWarning: Mean of empty slice
#   noise_mean = np.nanmean(filtered[annulus])
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/pyklip/klip.py:539: RuntimeWarning: Mean of empty slice
#   noise_mean = np.nanmean(filtered[annulus])
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2022-04-22 15:31:38,200 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
# Compute calibrated contrast
pipeline.cal_contrast()
# Out:
# --> Computing calibrated contrast curve...
# --> Mode = RDI, annuli = 1, subsections = 1, scenario 1 of 1
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# 2022-04-22 15:31:38,840 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# 2022-04-22 15:31:38,842 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:31:48,362 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:31:57,037 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:32:05,953 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:32:14,288 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:32:22,473 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:32:30,657 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:32:38,513 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:32:46,333 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:32:55,833 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:33:04,714 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:33:13,925 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# 2022-04-22 15:33:14,385 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# 2022-04-22 15:33:14,388 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)

# %%
# Extract companion photometry and astrometry
pipeline.companions()
# Out:
# --> Extracting companion properties...
# (array([      0,       2,       4,       6, 1049601, 1049603, 1049607,
#        1064961, 1064963, 1064965, 1065987, 4196353, 4196357, 5259265,
#        5259267, 5259269], dtype=uint32), array([403512,      4,   5075,     13,     20,    496,      4,    316,
#             8,     24,     44,     59,      5,     11,      8,      1]))
# [1505 1405 1565 1613]
# --> Rejected 0 of 4 images due to too many bad pixels (threshold = 10%)
# --> Rejected 0 of 18 images due to too many bad pixels (threshold = 10%)
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# 2022-04-22 15:33:19,576 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# 2022-04-22 15:33:19,578 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:1272: UserWarning:
# The coefficients of the spline returned have been computed as the
# minimal norm least-squares solution of a (numerically) rank deficient
# system (deficiency=483). If deficiency is large, the results may be
# inaccurate. Deficiency may strongly depend on the value of eps.
#   warnings.warn(message)
#
# 2022-04-22 15:33:23,448 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:1272: UserWarning:
# The coefficients of the spline returned have been computed as the
# minimal norm least-squares solution of a (numerically) rank deficient
# system (deficiency=483). If deficiency is large, the results may be
# inaccurate. Deficiency may strongly depend on the value of eps.
#   warnings.warn(message)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/scipy/interpolate/_fitpack2.py:1272: UserWarning:
# The coefficients of the spline returned have been computed as the
# minimal norm least-squares solution of a (numerically) rank deficient
# system (deficiency=483). If deficiency is large, the results may be
# inaccurate. Deficiency may strongly depend on the value of eps.
#   warnings.warn(message)
# Begin align and scale images for each wavelength
# Align and scale finished
# Starting KLIP for sector 1/1 with an area of 3245.672429867556 pix^2
# Time spent on last sector: 0s
# Time spent since beginning: 0s
# First sector: Can't predict remaining time
# **WARNING**: LOCAL JWST PRD VERSION PRDOPSSOC-044 DOESN'T MATCH THE CURRENT ONLINE VERSION PRDOPSSOC-045
# Please consider updating pysiaf, e.g. pip install --upgrade pysiaf or conda update pysiaf
# **WARNING**: LOCAL JWST PRD VERSION PRDOPSSOC-044 DOESN'T MATCH THE CURRENT ONLINE VERSION PRDOPSSOC-045
# Please consider updating pysiaf, e.g. pip install --upgrade pysiaf or conda update pysiaf
# **WARNING**: LOCAL JWST PRD VERSION PRDOPSSOC-044 DOESN'T MATCH THE CURRENT ONLINE VERSION PRDOPSSOC-045
# Please consider updating pysiaf, e.g. pip install --upgrade pysiaf or conda update pysiaf
# **WARNING**: LOCAL JWST PRD VERSION PRDOPSSOC-044 DOESN'T MATCH THE CURRENT ONLINE VERSION PRDOPSSOC-045
# Please consider updating pysiaf, e.g. pip install --upgrade pysiaf or conda update pysiaf
#
# Closing threadpool
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:33:29,003 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# 2022-04-22 15:33:29,063 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/astropy/wcs/wcs.py:2721: AstropyWarning: Some non-standard WCS keywords were excluded: A_ORDER, A_0_2, A_1_1, A_2_0, B_ORDER, B_0_2, B_1_1, B_2_0, AP_ORDER, AP_0_2, AP_1_1, AP_2_0, BP_ORDER, BP_0_2, BP_1_1, BP_2_0 Use the ``relax`` kwarg to control this.
#   warnings.warn(
# Writing KLIPed Images to directory /Users/acarter/Documents/DIRECT_IMAGING/CORONAGRAPHY_PIPELINE/TESTING/2022_04_22_RDI_annu1_subs1_run4/COMPANION/FITS
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# 2022-04-22 15:33:29,497 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# 2022-04-22 15:33:29,499 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# 2022-04-22 15:33:29,683 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/ensemble.py:98: DeprecationWarning: The 'threads' argument is deprecated
#   deprecation_warning("The 'threads' argument is deprecated")
#
# 2022-04-22 15:33:29,757 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/ensemble.py:98: DeprecationWarning: The 'threads' argument is deprecated
#   deprecation_warning("The 'threads' argument is deprecated")
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/ensemble.py:98: DeprecationWarning: The 'threads' argument is deprecated
#   deprecation_warning("The 'threads' argument is deprecated")
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/pyklip/fitpsf.py:673: DeprecationWarning: Please use `shift` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   fm_shifted = sinterp.shift(fma.fm_stamp, [dy, dx])
#
# 2022-04-22 15:33:29,762 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/pyklip/fitpsf.py:673: DeprecationWarning: Please use `shift` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   fm_shifted = sinterp.shift(fma.fm_stamp, [dy, dx])
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/pyklip/fitpsf.py:673: DeprecationWarning: Please use `shift` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   fm_shifted = sinterp.shift(fma.fm_stamp, [dy, dx])
# Running burn in
# Burn in finished. Now sampling posterior
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'chain' is deprecated. Use 'get_chain()' instead.
#   deprecation_warning(msg)
#
# 2022-04-22 15:34:21,855 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'chain' is deprecated. Use 'get_chain()' instead.
#   deprecation_warning(msg)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'chain' is deprecated. Use 'get_chain()' instead.
#   deprecation_warning(msg)
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'flatchain' is deprecated. Use 'get_chain(flat=True)' instead.
#   deprecation_warning(msg)
#
# 2022-04-22 15:34:21,857 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'flatchain' is deprecated. Use 'get_chain(flat=True)' instead.
#   deprecation_warning(msg)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'flatchain' is deprecated. Use 'get_chain(flat=True)' instead.
#   deprecation_warning(msg)
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'lnprobability' is deprecated. Use 'get_log_prob()' instead.
#   deprecation_warning(msg)
#
# 2022-04-22 15:34:21,862 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'lnprobability' is deprecated. Use 'get_log_prob()' instead.
#   deprecation_warning(msg)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'lnprobability' is deprecated. Use 'get_log_prob()' instead.
#   deprecation_warning(msg)
# MCMC sampler has finished
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'flatchain' is deprecated. Use 'get_chain(flat=True)' instead.
#   deprecation_warning(msg)
#
# 2022-04-22 15:34:22,472 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'flatchain' is deprecated. Use 'get_chain(flat=True)' instead.
#   deprecation_warning(msg)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/emcee/utils.py:23: DeprecationWarning: 'flatchain' is deprecated. Use 'get_chain(flat=True)' instead.
#   deprecation_warning(msg)
#
# [      root:WARNING] Too few points to create valid contours
# 2022-04-22 15:34:22,932 - stpipe - WARNING - Too few points to create valid contours
# [    stpipe:WARNING] Too few points to create valid contours
# [      root:WARNING] Too few points to create valid contours
# 2022-04-22 15:34:22,953 - stpipe - WARNING - Too few points to create valid contours
# [    stpipe:WARNING] Too few points to create valid contours
# [      root:WARNING] Too few points to create valid contours
# 2022-04-22 15:34:22,977 - stpipe - WARNING - Too few points to create valid contours
# [    stpipe:WARNING] Too few points to create valid contours
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# 2022-04-22 15:34:23,506 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# 2022-04-22 15:34:23,509 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/pyklip/fitpsf.py:569: DeprecationWarning: Please use `shift` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   fm_bestfit = self.fit_flux.bestfit * sinterp.shift(self.fm_stamp, [dy, dx])
#
# 2022-04-22 15:34:23,739 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/pyklip/fitpsf.py:569: DeprecationWarning: Please use `shift` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   fm_bestfit = self.fit_flux.bestfit * sinterp.shift(self.fm_stamp, [dy, dx])
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/pyklip/fitpsf.py:569: DeprecationWarning: Please use `shift` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   fm_bestfit = self.fit_flux.bestfit * sinterp.shift(self.fm_stamp, [dy, dx])
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# 2022-04-22 15:34:23,985 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1721: DeprecationWarning: NONE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   img = img.convert(mode='P', dither=Image.NONE,
#
# [py.warnings:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# 2022-04-22 15:34:23,987 - stpipe - WARNING - /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
#
# [    stpipe:WARNING] /Users/acarter/anaconda3/envs/sklip/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:1722: DeprecationWarning: ADAPTIVE is deprecated and will be removed in Pillow 10 (2023-07-01). Use Palette.ADAPTIVE instead.
#   palette=Image.ADAPTIVE, colors=num_colors)
# Companion 1
#    RA  = 412.34+/-0.56 mas (418.00 mas guess)
#    DEC = -707.30+/-0.35 mas (-698.00 mas guess)
#    CON = 2.72e-03+/-1.63e-05
